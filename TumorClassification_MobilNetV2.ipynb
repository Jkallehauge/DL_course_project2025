# %%
#Setting up paths for data
data_root = "/home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data/Brain-Tumor-Classification" 

tr_base  = data_root+"/Training"
te_base  = data_root+"/Testing"

# %%
#Setting up Transforms 
from pathlib import Path
from torch.utils.data import DataLoader, Subset, WeightedRandomSampler # remember subset when you divide into training and validation
from torchvision import datasets, transforms, utils, models # add models when you import pretrained models for transfer learning
import os
import torch
import numpy as np

IMG_SIZE = 512

def zscore(x):  # MRI-friendly
    return (x - x.mean()) / (x.std() + 1e-8)

train_tf = transforms.Compose([
    transforms.Lambda(lambda im: im.convert('L')),                 # use 'RGB' if truly 3-ch
    transforms.Grayscale(num_output_channels=3), 
    transforms.Resize((IMG_SIZE, IMG_SIZE), antialias=True),
    transforms.RandomAffine(degrees=10, translate=(0.02,0.02), scale=(0.95,1.05)),
    transforms.RandomApply([transforms.GaussianBlur(3, (0.1, 1.0))], p=0.2),
    transforms.ColorJitter(brightness=0.10, contrast=0.10),
    transforms.ToTensor(),
    #transforms.Lambda(zscore),
])

eval_tf = transforms.Compose([
    transforms.Lambda(lambda im: im.convert('L')),
    transforms.Grayscale(num_output_channels=3), 
    transforms.Resize((IMG_SIZE, IMG_SIZE), antialias=True),
    transforms.ToTensor(),
    #transforms.Lambda(zscore),
])

# %%
trainset=datasets.ImageFolder(tr_base, transform=train_tf)
valset = datasets.ImageFolder(tr_base, transform=eval_tf)
testset=datasets.ImageFolder(te_base, transform=eval_tf)


print(testset.classes)
print(trainset.classes)
print(valset.classes)

val_fraction=0.2

idxs = list(range(len(valset)))
rng = np.random.default_rng(42)
rng.shuffle(idxs)

n_val = int(len(idxs) * val_fraction)
val_idx = idxs[:n_val]
train_idx = idxs[n_val:]

trainset = Subset(trainset, train_idx)
valset   = Subset(valset,   val_idx)

class_names = datasets.ImageFolder(tr_base).classes
# Out:
# ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
# ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
# ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

# %%
def get_targets_from_dataset(ds) -> np.ndarray:
    """Return class indices for ImageFolder or Subset(ImageFolder)."""
    if isinstance(ds, Subset):
        base, idxs = ds.dataset, ds.indices
        if hasattr(base, "targets"):
            return np.asarray(base.targets, dtype=int)[idxs]
        return np.asarray([base.samples[i][1] for i in idxs], dtype=int)
    # ImageFolder
    if hasattr(ds, "targets"):
        return np.asarray(ds.targets, dtype=int)
    return np.asarray([y for _, y in ds.samples], dtype=int)

# %%
# assume you already created trainset (ImageFolder or Subset(ImageFolder))
targets = get_targets_from_dataset(trainset)              # shape [N]
num_classes = int(targets.max() + 1)

# inverse-frequency class weights (simple & effective)
class_counts  = np.bincount(targets, minlength=num_classes).astype(float)
class_weights = 1.0 / np.maximum(class_counts, 1.0)      # avoid div/0
sample_weights = class_weights[targets]                   # per-sample weight

sampler = WeightedRandomSampler(
    weights=torch.as_tensor(sample_weights, dtype=torch.double),
    num_samples=len(sample_weights),   # one epoch ~= dataset size
    replacement=True                   # allows oversampling of minority class
)

BATCH = 4
WORKERS = 4


train_loader = DataLoader(
    trainset,
    batch_size=BATCH,
    shuffle=False,
    sampler=sampler,
    num_workers=WORKERS,
    pin_memory=True,
    drop_last=True,                    # optional: keeps batch size stable
)

# validation/test loaders stay standard (no sampler)
val_loader = DataLoader(valset, batch_size=64, shuffle=False, num_workers=WORKERS, pin_memory=True)

# %%
import torch.nn as nn
from torchvision import models

def build_model(n_classes, freeze_backbone=False):
    """
    Build a Swin Transformer Base model pretrained on ImageNet-1K,
    replace classification head for custom number of classes,
    and optionally freeze backbone layers.
    """
    # 1️⃣ Load pretrained Swin Transformer Base
    model = models.mobilenet_v2(weights=models.MobileNet_V2_Weights.IMAGENET1K_V1)
    

    # 2️⃣ Replace classifier head
    in_feats = model.classifier[-1].in_features
    model.classifier[-1] = nn.Linear(in_feats, n_classes)
    if freeze_backbone:
        for p in model.features.parameters():
            p.requires_grad = False
    return model


model = build_model(n_classes=4, freeze_backbone=False)
print(model)

# Verify output
import torch
x = torch.randn(2, 3, 512, 512)
out = model(x)
print(out.shape)  # → [2, 4]
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=4, bias=True)
#   )
# )
# torch.Size([2, 4])

# %%
# ----------------------------
# 3) Training utilities
# ----------------------------
class EarlyStopper:
    def __init__(self, patience=8, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best = None
        self.count = 0

    def step(self, metric):
        if self.best is None or metric > self.best + self.min_delta:
            self.best = metric
            self.count = 0
            return False  # do not stop

# %%
import contextlib
import torch
import torch.nn.functional as F

def epoch_run(model, loader, criterion, device, train: bool, use_amp: bool,
              optimizer=None, scaler=None):
    assert (train and optimizer is not None and scaler is not None) or (not train)

    model.train() if train else model.eval()

    total = 0
    running_loss = 0.0
    correct = 0

    # no graph during evaluation
    cm = contextlib.nullcontext() if train else torch.no_grad()

    with cm:
        for xb, yb in loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)

            with torch.amp.autocast('cuda', enabled=(use_amp and device.type == 'cuda')):
                logits = model(xb)
                loss = criterion(logits, yb)

            if train:
                optimizer.zero_grad(set_to_none=True)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

            running_loss += loss.detach().float().item() * xb.size(0)
            pred = logits.argmax(1)
            correct += (pred == yb).sum().item()
            total += yb.size(0)

    return running_loss / total, correct / total

# %%
def set_seed(seed=42):
    random.seed(seed); np.random.seed(seed); torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

def get_device():
    return torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def to_device(batch, device):
    x, y = batch
    return x.to(device, non_blocking=True), y.to(device, non_blocking=True)

# %%
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import Counter
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from torch import amp
import json

seed=2025
set_seed(seed)
device = get_device()
print("Device:", device)

DATA_ROOT = data_root 
BATCH = 32
EPOCHS = 500
LR = 3e-4
FREEZE_BACKBONE = False  # set True to train only the last layer first

#trainset, valset, testset, class_names = build_datasets(DATA_ROOT, img_size=224, val_fraction=0.15)
print("Classes:", class_names)

scaler = amp.GradScaler('cuda', enabled=(device.type=='cuda'))

train_loader = DataLoader(trainset,batch_size=BATCH,sampler=sampler,num_workers=WORKERS,pin_memory=True)                    # optional: keeps batch size stable)
val_loader = DataLoader(valset, batch_size=BATCH*2, shuffle=False,num_workers=WORKERS, pin_memory=True, drop_last=False)
test_loader = DataLoader(testset, batch_size=BATCH*2, shuffle=False,num_workers=WORKERS, pin_memory=True, drop_last=False)   

print("Train uses sampler:", train_loader.sampler.__class__.__name__)
print("Val uses sampler:  ", val_loader.sampler.__class__.__name__)
print("Test uses sampler: ", test_loader.sampler.__class__.__name__)

model = build_model(n_classes=len(class_names), freeze_backbone=FREEZE_BACKBONE)
model.to(device)

#model = CNN512x3(num_classes=4, in_ch=3, dropout=0.5).to(device)
#criterion = nn.CrossEntropyLoss()  
criterion = torch.nn.CrossEntropyLoss(label_smoothing=0.05)
#criterion = FocalLoss(
#    gamma=1.5,    # 1.0 = CE; 1.5–2.0 is often best
#    reduction='mean'
#)
optimizer = torch.optim.AdamW(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

history = {
    "train_loss": [],
    "val_loss":   [],
    "train_acc":  [],
    "val_acc":    [],
}


best_loss, best_acc, best_path, best_path_acc = 1000, 0.0, "best_MobileNetV2_Loss_brain_tumor.pt", "best_MobileNetV2_Acc_brain_tumor.pt"
stopper = EarlyStopper(patience=7, min_delta=1e-4)

for epoch in range(1, EPOCHS+1):
    #train_loss, train_acc = epoch_run(model, train_loader, criterion, device, train=True, use_amp=True)
    #val_loss,   val_acc   = epoch_run(model, val_loader,   criterion, device, train=False, use_amp=True)
    
    train_loss, train_acc = epoch_run(model, train_loader, criterion, device, train=True, use_amp=True, optimizer=optimizer, scaler=scaler)
    val_loss,   val_acc   = epoch_run(model, val_loader,   criterion, device, train=False, use_amp=True)
    #scheduler.step(val_loss)
    scheduler.step()

    # log
    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)

    color = ""
    end_color = "\033[0m"
    style_bold = "\033[1m"
    suffix = ""

    # Check for improvements
    if val_loss < best_loss and val_acc > best_acc:
        best_loss = val_loss
        best_acc = val_acc
        color = "\033[96m"  # cyan if both improve
        suffix = " 🟢⭐ (new best loss & acc)"
        torch.save({"model": model.state_dict(),
                    "classes": class_names}, best_path)

    elif val_loss < best_loss:
        best_loss = val_loss
        color = "\033[92m"  # green for best loss
        suffix = " ✅ (new best loss)"
        torch.save({"model": model.state_dict(),
                    "classes": class_names}, best_path)
    elif val_acc > best_acc:
        best_acc = val_acc
        color = "\033[94m"  # blue for best acc
        suffix = " 💙 (new best acc)"
        torch.save({"model": model.state_dict(),
                    "classes": class_names}, best_path_acc)

    # Print the formatted line
    print(f"{color}{style_bold}"
          f"Epoch {epoch:02d}/{EPOCHS} | "
          f"train_loss={train_loss:.4f} acc={train_acc:.4f} | "
          f"val_loss={val_loss:.4f} acc={val_acc:.4f}"
          f"{suffix}{end_color}")


    if stopper.step(val_acc):
        print("Early stopping triggered.")
        break


print(f"Best val loss: {best_loss:.4f}. Saved to: {best_path}")

with open("history_MobileNetV2.json", "w") as f:
    json.dump(history, f)


# ---- after training: plots ----
epochs = range(1, len(history["train_loss"]) + 1)

plt.figure()
plt.plot(epochs, history["train_loss"], label="Train loss")
plt.plot(epochs, history["val_loss"],   label="Val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# (optional) accuracy plot
plt.figure()
plt.plot(epochs, history["train_acc"], label="Train acc")
plt.plot(epochs, history["val_acc"],   label="Val acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# ----------------------------
# Evaluation on test (if available)
# ----------------------------
if test_loader is not None:
    ckpt = torch.load(best_path, map_location=device)
    model.load_state_dict(ckpt["model"])
    model.eval()
    all_preds, all_tgts = [], []
    with torch.no_grad():
        for xb, yb in test_loader:
            xb, yb = to_device((xb, yb), device)
            logits = model(xb)
            all_preds.append(logits.argmax(1).cpu())
            all_tgts.append(yb.cpu())


    y_pred = torch.cat(all_preds).numpy()
    y_true = torch.cat(all_tgts).numpy()
    print("\nTest classification report:")
    print(classification_report(y_true, y_pred, target_names= class_names, digits=4))
    print("\nConfusion matrix:")
    print(confusion_matrix(y_true, y_pred))
# Out:
# Device: cuda
# Classes: ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
# Train uses sampler: WeightedRandomSampler
# Val uses sampler:   SequentialSampler
# Test uses sampler:  SequentialSampler
# Epoch 01/500 | train_loss=0.5628 acc=0.8376 | val_loss=0.5811 acc=0.8504 🟢⭐ (new best loss & acc)
# Epoch 02/500 | train_loss=0.3486 acc=0.9475 | val_loss=0.3572 acc=0.9513 🟢⭐ (new best loss & acc)
# Epoch 03/500 | train_loss=0.3105 acc=0.9696 | val_loss=0.3103 acc=0.9617 🟢⭐ (new best loss & acc)
# Epoch 04/500 | train_loss=0.2789 acc=0.9809 | val_loss=0.3154 acc=0.9635 💙 (new best acc)
# Epoch 05/500 | train_loss=0.2755 acc=0.9792 | val_loss=0.3269 acc=0.9496
# Epoch 06/500 | train_loss=0.2586 acc=0.9887 | val_loss=0.2733 acc=0.9757 🟢⭐ (new best loss & acc)
# Epoch 07/500 | train_loss=0.2505 acc=0.9909 | val_loss=0.2734 acc=0.9774 💙 (new best acc)
# Epoch 08/500 | train_loss=0.2412 acc=0.9944 | val_loss=0.2661 acc=0.9843 🟢⭐ (new best loss & acc)
# Epoch 09/500 | train_loss=0.2330 acc=0.9961 | val_loss=0.2680 acc=0.9774
# Epoch 10/500 | train_loss=0.2276 acc=0.9987 | val_loss=0.2689 acc=0.9757
# Epoch 11/500 | train_loss=0.2292 acc=0.9987 | val_loss=0.2706 acc=0.9774
# Epoch 12/500 | train_loss=0.2232 acc=0.9983 | val_loss=0.2631 acc=0.9809 ✅ (new best loss)
# Epoch 13/500 | train_loss=0.2212 acc=0.9991 | val_loss=0.2536 acc=0.9809 ✅ (new best loss)
# Epoch 14/500 | train_loss=0.2192 acc=0.9991 | val_loss=0.2791 acc=0.9704
# Epoch 15/500 | train_loss=0.2188 acc=1.0000 | val_loss=0.2699 acc=0.9739
# Epoch 16/500 | train_loss=0.2351 acc=0.9935 | val_loss=0.2941 acc=0.9722
# Epoch 17/500 | train_loss=0.2278 acc=0.9974 | val_loss=0.2525 acc=0.9878 🟢⭐ (new best loss & acc)
# Epoch 18/500 | train_loss=0.2235 acc=0.9974 | val_loss=0.2697 acc=0.9774
# Epoch 19/500 | train_loss=0.2216 acc=0.9970 | val_loss=0.2581 acc=0.9791
# Epoch 20/500 | train_loss=0.2225 acc=0.9965 | val_loss=0.2695 acc=0.9774
# Epoch 21/500 | train_loss=0.2207 acc=0.9996 | val_loss=0.2548 acc=0.9809
# Epoch 22/500 | train_loss=0.2169 acc=0.9987 | val_loss=0.2588 acc=0.9757
# Epoch 23/500 | train_loss=0.2117 acc=0.9996 | val_loss=0.2530 acc=0.9791
# Epoch 24/500 | train_loss=0.2104 acc=1.0000 | val_loss=0.3177 acc=0.9530
# Epoch 25/500 | train_loss=0.2173 acc=0.9978 | val_loss=0.2463 acc=0.9791 ✅ (new best loss)
# Epoch 26/500 | train_loss=0.2111 acc=0.9996 | val_loss=0.2432 acc=0.9843 ✅ (new best loss)
# Epoch 27/500 | train_loss=0.2080 acc=1.0000 | val_loss=0.2374 acc=0.9878 ✅ (new best loss)
# Epoch 28/500 | train_loss=0.2075 acc=1.0000 | val_loss=0.2315 acc=0.9878 ✅ (new best loss)
# Epoch 29/500 | train_loss=0.2067 acc=1.0000 | val_loss=0.2367 acc=0.9878
# Epoch 30/500 | train_loss=0.2066 acc=1.0000 | val_loss=0.2314 acc=0.9878 ✅ (new best loss)
# Epoch 31/500 | train_loss=0.2175 acc=0.9965 | val_loss=0.2503 acc=0.9843
# Epoch 32/500 | train_loss=0.2255 acc=0.9970 | val_loss=0.2503 acc=0.9861
# Epoch 33/500 | train_loss=0.2518 acc=0.9878 | val_loss=0.6321 acc=0.8591
# Epoch 34/500 | train_loss=0.2546 acc=0.9865 | val_loss=0.3152 acc=0.9617
# Epoch 35/500 | train_loss=0.2301 acc=0.9948 | val_loss=0.2871 acc=0.9704
# Epoch 36/500 | train_loss=0.2176 acc=0.9987 | val_loss=0.2399 acc=0.9861
# Epoch 37/500 | train_loss=0.2192 acc=0.9970 | val_loss=0.2856 acc=0.9739
# Epoch 38/500 | train_loss=0.2137 acc=0.9991 | val_loss=0.2430 acc=0.9843
# Epoch 39/500 | train_loss=0.2140 acc=0.9987 | val_loss=0.2526 acc=0.9809
# Epoch 40/500 | train_loss=0.2176 acc=0.9978 | val_loss=0.2485 acc=0.9826
# Epoch 41/500 | train_loss=0.2160 acc=0.9983 | val_loss=0.2477 acc=0.9809
# Epoch 42/500 | train_loss=0.2193 acc=0.9957 | val_loss=0.2575 acc=0.9826
# Epoch 43/500 | train_loss=0.2156 acc=0.9987 | val_loss=0.2403 acc=0.9826
# Epoch 44/500 | train_loss=0.2151 acc=0.9978 | val_loss=0.3507 acc=0.9409
# Epoch 45/500 | train_loss=0.2156 acc=0.9983 | val_loss=0.2391 acc=0.9826
# Epoch 46/500 | train_loss=0.2086 acc=1.0000 | val_loss=0.2350 acc=0.9861
# Epoch 47/500 | train_loss=0.2057 acc=1.0000 | val_loss=0.2292 acc=0.9913 🟢⭐ (new best loss & acc)
# Epoch 48/500 | train_loss=0.2060 acc=1.0000 | val_loss=0.2315 acc=0.9896
# Epoch 49/500 | train_loss=0.2053 acc=1.0000 | val_loss=0.2372 acc=0.9878
# Epoch 50/500 | train_loss=0.2047 acc=1.0000 | val_loss=0.2290 acc=0.9930 🟢⭐ (new best loss & acc)
# Epoch 51/500 | train_loss=0.2048 acc=1.0000 | val_loss=0.2291 acc=0.9913
# Epoch 52/500 | train_loss=0.2041 acc=1.0000 | val_loss=0.2273 acc=0.9930 ✅ (new best loss)
# Epoch 53/500 | train_loss=0.2038 acc=1.0000 | val_loss=0.2287 acc=0.9930
# Epoch 54/500 | train_loss=0.2036 acc=1.0000 | val_loss=0.2227 acc=0.9948 🟢⭐ (new best loss & acc)
# Epoch 55/500 | train_loss=0.2035 acc=1.0000 | val_loss=0.2237 acc=0.9930
# Epoch 56/500 | train_loss=0.2036 acc=1.0000 | val_loss=0.2224 acc=0.9965 🟢⭐ (new best loss & acc)
# Epoch 57/500 | train_loss=0.2030 acc=1.0000 | val_loss=0.2258 acc=0.9913
# Epoch 58/500 | train_loss=0.2035 acc=1.0000 | val_loss=0.2252 acc=0.9896
# Epoch 59/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.2223 acc=0.9930 ✅ (new best loss)
# Epoch 60/500 | train_loss=0.2033 acc=1.0000 | val_loss=0.2247 acc=0.9930
# Epoch 61/500 | train_loss=0.2033 acc=1.0000 | val_loss=0.2403 acc=0.9843
# Epoch 62/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.2286 acc=0.9896
# Epoch 63/500 | train_loss=0.2029 acc=1.0000 | val_loss=0.2291 acc=0.9896
# Epoch 64/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.2287 acc=0.9896
# Epoch 65/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.2282 acc=0.9878
# Epoch 66/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.2288 acc=0.9896
# Epoch 67/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.2249 acc=0.9896
# Epoch 68/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.2290 acc=0.9878
# Epoch 69/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.2350 acc=0.9861
# Epoch 70/500 | train_loss=0.2030 acc=1.0000 | val_loss=0.2255 acc=0.9913
# Epoch 71/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.2290 acc=0.9878
# Epoch 72/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.2254 acc=0.9913
# Epoch 73/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.2259 acc=0.9896
# Epoch 74/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.2290 acc=0.9896
# Epoch 75/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2283 acc=0.9913
# Epoch 76/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.2296 acc=0.9896
# Epoch 77/500 | train_loss=0.2700 acc=0.9761 | val_loss=0.5880 acc=0.8574
# Epoch 78/500 | train_loss=0.2967 acc=0.9696 | val_loss=0.2923 acc=0.9704
# Epoch 79/500 | train_loss=0.2510 acc=0.9874 | val_loss=0.2666 acc=0.9757
# Epoch 80/500 | train_loss=0.2301 acc=0.9939 | val_loss=0.2716 acc=0.9774
# Epoch 81/500 | train_loss=0.2174 acc=0.9970 | val_loss=0.2585 acc=0.9739
# Epoch 82/500 | train_loss=0.2087 acc=0.9991 | val_loss=0.2325 acc=0.9930
# Epoch 83/500 | train_loss=0.2066 acc=1.0000 | val_loss=0.2281 acc=0.9913
# Epoch 84/500 | train_loss=0.2089 acc=0.9987 | val_loss=0.2497 acc=0.9809
# Epoch 85/500 | train_loss=0.2078 acc=0.9991 | val_loss=0.2209 acc=0.9930 ✅ (new best loss)
# Epoch 86/500 | train_loss=0.2087 acc=0.9978 | val_loss=0.2394 acc=0.9843
# Epoch 87/500 | train_loss=0.2142 acc=0.9974 | val_loss=0.2440 acc=0.9809
# Epoch 88/500 | train_loss=0.2066 acc=0.9996 | val_loss=0.2291 acc=0.9861
# Epoch 89/500 | train_loss=0.2042 acc=1.0000 | val_loss=0.2281 acc=0.9896
# Epoch 90/500 | train_loss=0.2041 acc=1.0000 | val_loss=0.2263 acc=0.9878
# Epoch 91/500 | train_loss=0.2046 acc=0.9996 | val_loss=0.2436 acc=0.9826
# Epoch 92/500 | train_loss=0.2071 acc=0.9991 | val_loss=0.2348 acc=0.9843
# Epoch 93/500 | train_loss=0.2063 acc=0.9996 | val_loss=0.2650 acc=0.9757
# Epoch 94/500 | train_loss=0.2067 acc=0.9996 | val_loss=0.2265 acc=0.9913
# Epoch 95/500 | train_loss=0.2043 acc=1.0000 | val_loss=0.2239 acc=0.9913
# Epoch 96/500 | train_loss=0.2038 acc=1.0000 | val_loss=0.2257 acc=0.9930
# Epoch 97/500 | train_loss=0.2031 acc=1.0000 | val_loss=0.2210 acc=0.9930
# Epoch 98/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.2234 acc=0.9896
# Epoch 99/500 | train_loss=0.2033 acc=1.0000 | val_loss=0.2238 acc=0.9913
# Epoch 100/500 | train_loss=0.2034 acc=1.0000 | val_loss=0.2304 acc=0.9878
# Epoch 101/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.2220 acc=0.9913
# Epoch 102/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.2248 acc=0.9896
# Epoch 103/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.2290 acc=0.9896
# Epoch 104/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.2245 acc=0.9896
# Epoch 105/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.2266 acc=0.9913
# Epoch 106/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.2266 acc=0.9913
# Epoch 107/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.2206 acc=0.9913 ✅ (new best loss)
# Epoch 108/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.2216 acc=0.9896
# Epoch 109/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2222 acc=0.9896
# Epoch 110/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.2319 acc=0.9843
# Epoch 111/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.2306 acc=0.9843
# Epoch 112/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2290 acc=0.9896
# Epoch 113/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2414 acc=0.9826
# Epoch 114/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2362 acc=0.9861
# Epoch 115/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2281 acc=0.9896
# Epoch 116/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2340 acc=0.9878
# Epoch 117/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.2272 acc=0.9861
# Epoch 118/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.2295 acc=0.9878
# Epoch 119/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2277 acc=0.9878
# Epoch 120/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2286 acc=0.9861
# Epoch 121/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2262 acc=0.9896
# Epoch 122/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2320 acc=0.9861
# Epoch 123/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2270 acc=0.9878
# Epoch 124/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2344 acc=0.9861
# Epoch 125/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2281 acc=0.9896
# Epoch 126/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2268 acc=0.9913
# Epoch 127/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2347 acc=0.9861
# Epoch 128/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2273 acc=0.9913
# Epoch 129/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2284 acc=0.9861
# Epoch 130/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2215 acc=0.9913
# Epoch 131/500 | train_loss=0.2625 acc=0.9787 | val_loss=0.4491 acc=0.9270
# Epoch 132/500 | train_loss=0.3038 acc=0.9657 | val_loss=0.4875 acc=0.8852
# Epoch 133/500 | train_loss=0.2362 acc=0.9896 | val_loss=0.2466 acc=0.9826
# Epoch 134/500 | train_loss=0.2177 acc=0.9970 | val_loss=0.2342 acc=0.9930
# Epoch 135/500 | train_loss=0.2088 acc=0.9991 | val_loss=0.2382 acc=0.9843
# Epoch 136/500 | train_loss=0.2129 acc=0.9974 | val_loss=0.2482 acc=0.9809
# Epoch 137/500 | train_loss=0.2080 acc=0.9991 | val_loss=0.2433 acc=0.9791
# Epoch 138/500 | train_loss=0.2061 acc=1.0000 | val_loss=0.2303 acc=0.9878
# Epoch 139/500 | train_loss=0.2047 acc=1.0000 | val_loss=0.2348 acc=0.9861
# Epoch 140/500 | train_loss=0.2039 acc=1.0000 | val_loss=0.2307 acc=0.9878
# Epoch 141/500 | train_loss=0.2033 acc=1.0000 | val_loss=0.2327 acc=0.9878
# Epoch 142/500 | train_loss=0.2031 acc=1.0000 | val_loss=0.2287 acc=0.9896
# Epoch 143/500 | train_loss=0.2034 acc=1.0000 | val_loss=0.2329 acc=0.9878
# Epoch 144/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.2278 acc=0.9878
# Epoch 145/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.2297 acc=0.9878
# Epoch 146/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.2288 acc=0.9861
# Epoch 147/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.2333 acc=0.9861
# Epoch 148/500 | train_loss=0.2036 acc=1.0000 | val_loss=0.2421 acc=0.9791
# Epoch 149/500 | train_loss=0.2060 acc=0.9983 | val_loss=0.2639 acc=0.9757
# Epoch 150/500 | train_loss=0.2167 acc=0.9957 | val_loss=0.2526 acc=0.9757
# Epoch 151/500 | train_loss=0.2071 acc=0.9991 | val_loss=0.2466 acc=0.9774
# Epoch 152/500 | train_loss=0.2060 acc=0.9996 | val_loss=0.2381 acc=0.9826
# Epoch 153/500 | train_loss=0.2075 acc=0.9983 | val_loss=0.2379 acc=0.9843
# Epoch 154/500 | train_loss=0.2046 acc=1.0000 | val_loss=0.2430 acc=0.9809
# Epoch 155/500 | train_loss=0.2042 acc=0.9996 | val_loss=0.2367 acc=0.9861
# Epoch 156/500 | train_loss=0.2029 acc=1.0000 | val_loss=0.2289 acc=0.9861
# Epoch 157/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.2282 acc=0.9896
# Epoch 158/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.2331 acc=0.9878
# Epoch 159/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.2299 acc=0.9861
# Epoch 160/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.2285 acc=0.9861
# Epoch 161/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2267 acc=0.9896
# Epoch 162/500 | train_loss=0.2064 acc=0.9996 | val_loss=0.2348 acc=0.9826
# Epoch 163/500 | train_loss=0.2029 acc=1.0000 | val_loss=0.2324 acc=0.9861
# Epoch 164/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.2321 acc=0.9843
# Epoch 165/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.2315 acc=0.9843
# Epoch 166/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2291 acc=0.9878
# Epoch 167/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2298 acc=0.9861
# Epoch 168/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.2257 acc=0.9913
# Epoch 169/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2266 acc=0.9913
# Epoch 170/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2283 acc=0.9896
# Epoch 171/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2274 acc=0.9896
# Epoch 172/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2277 acc=0.9896
# Epoch 173/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2299 acc=0.9861
# Epoch 174/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2298 acc=0.9878
# Epoch 175/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2280 acc=0.9878
# Epoch 176/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2270 acc=0.9861
# Epoch 177/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2288 acc=0.9878
# Epoch 178/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2295 acc=0.9861
# Epoch 179/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2301 acc=0.9861
# Epoch 180/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2319 acc=0.9826
# Epoch 181/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2317 acc=0.9843
# Epoch 182/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2287 acc=0.9878
# Epoch 183/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2301 acc=0.9861
# Epoch 184/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2254 acc=0.9878
# Epoch 185/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2281 acc=0.9878
# Epoch 186/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2284 acc=0.9843
# Epoch 187/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2289 acc=0.9878
# Epoch 188/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2283 acc=0.9878
# Epoch 189/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2248 acc=0.9896
# Epoch 190/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2283 acc=0.9878
# Epoch 191/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2435 acc=0.9791
# Epoch 192/500 | train_loss=0.2099 acc=0.9978 | val_loss=0.2882 acc=0.9826
# Epoch 193/500 | train_loss=0.2490 acc=0.9870 | val_loss=0.2801 acc=0.9670
# Epoch 194/500 | train_loss=0.2304 acc=0.9913 | val_loss=0.2451 acc=0.9809
# Epoch 195/500 | train_loss=0.2137 acc=0.9965 | val_loss=0.2422 acc=0.9791
# Epoch 196/500 | train_loss=0.2132 acc=0.9970 | val_loss=0.2267 acc=0.9913
# Epoch 197/500 | train_loss=0.2076 acc=0.9996 | val_loss=0.2234 acc=0.9913
# Epoch 198/500 | train_loss=0.2040 acc=0.9996 | val_loss=0.2269 acc=0.9896
# Epoch 199/500 | train_loss=0.2036 acc=1.0000 | val_loss=0.2203 acc=0.9896 ✅ (new best loss)
# Epoch 200/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.2173 acc=0.9913 ✅ (new best loss)
# Epoch 201/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.2164 acc=0.9948 ✅ (new best loss)
# Epoch 202/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.2187 acc=0.9948
# Epoch 203/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.2177 acc=0.9930
# Epoch 204/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2164 acc=0.9930
# Epoch 205/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2168 acc=0.9930
# Epoch 206/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.2131 acc=0.9983 🟢⭐ (new best loss & acc)
# Epoch 207/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2156 acc=0.9948
# Epoch 208/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2157 acc=0.9965
# Epoch 209/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2170 acc=0.9948
# Epoch 210/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2187 acc=0.9930
# Epoch 211/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2166 acc=0.9948
# Epoch 212/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2148 acc=0.9965
# Epoch 213/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2166 acc=0.9948
# Epoch 214/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2168 acc=0.9948
# Epoch 215/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2164 acc=0.9948
# Epoch 216/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2180 acc=0.9930
# Epoch 217/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2189 acc=0.9913
# Epoch 218/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2161 acc=0.9948
# Epoch 219/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2161 acc=0.9930
# Epoch 220/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2179 acc=0.9930
# Epoch 221/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2176 acc=0.9930
# Epoch 222/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2177 acc=0.9948
# Epoch 223/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2159 acc=0.9948
# Epoch 224/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2144 acc=0.9948
# Epoch 225/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2166 acc=0.9965
# Epoch 226/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2170 acc=0.9948
# Epoch 227/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2174 acc=0.9930
# Epoch 228/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2208 acc=0.9930
# Epoch 229/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2156 acc=0.9948
# Epoch 230/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2148 acc=0.9948
# Epoch 231/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2168 acc=0.9965
# Epoch 232/500 | train_loss=0.2036 acc=0.9996 | val_loss=0.2274 acc=0.9843
# Epoch 233/500 | train_loss=0.2201 acc=0.9944 | val_loss=0.2732 acc=0.9670
# Epoch 234/500 | train_loss=0.2143 acc=0.9974 | val_loss=0.2742 acc=0.9704
# Epoch 235/500 | train_loss=0.2115 acc=0.9978 | val_loss=0.2760 acc=0.9704
# Epoch 236/500 | train_loss=0.2087 acc=0.9983 | val_loss=0.2664 acc=0.9704
# Epoch 237/500 | train_loss=0.2071 acc=0.9987 | val_loss=0.2426 acc=0.9861
# Epoch 238/500 | train_loss=0.2047 acc=0.9991 | val_loss=0.2361 acc=0.9878
# Epoch 239/500 | train_loss=0.2033 acc=1.0000 | val_loss=0.2346 acc=0.9861
# Epoch 240/500 | train_loss=0.2040 acc=0.9996 | val_loss=0.2282 acc=0.9861
# Epoch 241/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.2305 acc=0.9861
# Epoch 242/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.2379 acc=0.9843
# Epoch 243/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2309 acc=0.9878
# Epoch 244/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.2313 acc=0.9861
# Epoch 245/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.2279 acc=0.9878
# Epoch 246/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2269 acc=0.9878
# Epoch 247/500 | train_loss=0.2027 acc=0.9996 | val_loss=0.2247 acc=0.9878
# Epoch 248/500 | train_loss=0.2044 acc=0.9987 | val_loss=0.2587 acc=0.9757
# Epoch 249/500 | train_loss=0.2071 acc=0.9978 | val_loss=0.2297 acc=0.9861
# Epoch 250/500 | train_loss=0.2031 acc=0.9996 | val_loss=0.2430 acc=0.9826
# Epoch 251/500 | train_loss=0.2029 acc=1.0000 | val_loss=0.2380 acc=0.9843
# Epoch 252/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.2349 acc=0.9826
# Epoch 253/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2399 acc=0.9826
# Epoch 254/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.2348 acc=0.9826
# Epoch 255/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2339 acc=0.9843
# Epoch 256/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2377 acc=0.9826
# Epoch 257/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2364 acc=0.9826
# Epoch 258/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2352 acc=0.9826
# Epoch 259/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2318 acc=0.9861
# Epoch 260/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2320 acc=0.9843
# Epoch 261/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2316 acc=0.9826
# Epoch 262/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2331 acc=0.9826
# Epoch 263/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2253 acc=0.9878
# Epoch 264/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2301 acc=0.9878
# Epoch 265/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2308 acc=0.9843
# Epoch 266/500 | train_loss=0.2057 acc=0.9987 | val_loss=0.2285 acc=0.9878
# Epoch 267/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2321 acc=0.9878
# Epoch 268/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2304 acc=0.9861
# Epoch 269/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2311 acc=0.9861
# Epoch 270/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2307 acc=0.9878
# Epoch 271/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2276 acc=0.9861
# Epoch 272/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2288 acc=0.9861
# Epoch 273/500 | train_loss=0.2036 acc=0.9996 | val_loss=0.2395 acc=0.9843
# Epoch 274/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2342 acc=0.9878
# Epoch 275/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2325 acc=0.9861
# Epoch 276/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2324 acc=0.9861
# Epoch 277/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2297 acc=0.9861
# Epoch 278/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2316 acc=0.9878
# Epoch 279/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2302 acc=0.9878
# Epoch 280/500 | train_loss=0.2030 acc=0.9996 | val_loss=0.2753 acc=0.9635
# Epoch 281/500 | train_loss=0.2077 acc=0.9987 | val_loss=0.2316 acc=0.9861
# Epoch 282/500 | train_loss=0.2076 acc=0.9978 | val_loss=0.2774 acc=0.9635
# Epoch 283/500 | train_loss=0.2103 acc=0.9965 | val_loss=0.2387 acc=0.9809
# Epoch 284/500 | train_loss=0.2034 acc=1.0000 | val_loss=0.2251 acc=0.9896
# Epoch 285/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.2246 acc=0.9878
# Epoch 286/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.2228 acc=0.9913
# Epoch 287/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.2241 acc=0.9913
# Epoch 288/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2227 acc=0.9913
# Epoch 289/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2246 acc=0.9913
# Epoch 290/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.2229 acc=0.9930
# Epoch 291/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2249 acc=0.9896
# Epoch 292/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2232 acc=0.9913
# Epoch 293/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2222 acc=0.9930
# Epoch 294/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2260 acc=0.9913
# Epoch 295/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2214 acc=0.9913
# Epoch 296/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2183 acc=0.9930
# Epoch 297/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2185 acc=0.9948
# Epoch 298/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2178 acc=0.9948
# Epoch 299/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2193 acc=0.9930
# Epoch 300/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2201 acc=0.9930
# Epoch 301/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2206 acc=0.9930
# Epoch 302/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2197 acc=0.9930
# Epoch 303/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2198 acc=0.9930
# Epoch 304/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2215 acc=0.9930
# Epoch 305/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2225 acc=0.9930
# Epoch 306/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2214 acc=0.9930
# Epoch 307/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2215 acc=0.9930
# Epoch 308/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2213 acc=0.9930
# Epoch 309/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2207 acc=0.9930
# Epoch 310/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2196 acc=0.9930
# Epoch 311/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2189 acc=0.9930
# Epoch 312/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2220 acc=0.9930
# Epoch 313/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2223 acc=0.9930
# Epoch 314/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2191 acc=0.9930
# Epoch 315/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2194 acc=0.9930
# Epoch 316/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2204 acc=0.9930
# Epoch 317/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2210 acc=0.9930
# Epoch 318/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2209 acc=0.9913
# Epoch 319/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2226 acc=0.9930
# Epoch 320/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2210 acc=0.9930
# Epoch 321/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2212 acc=0.9930
# Epoch 322/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2201 acc=0.9913
# Epoch 323/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2212 acc=0.9913
# Epoch 324/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2203 acc=0.9930
# Epoch 325/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2229 acc=0.9930
# Epoch 326/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2207 acc=0.9930
# Epoch 327/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2224 acc=0.9913
# Epoch 328/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2243 acc=0.9861
# Epoch 329/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2246 acc=0.9913
# Epoch 330/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2234 acc=0.9913
# Epoch 331/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2233 acc=0.9913
# Epoch 332/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2223 acc=0.9930
# Epoch 333/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2212 acc=0.9913
# Epoch 334/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2198 acc=0.9930
# Epoch 335/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2196 acc=0.9930
# Epoch 336/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2186 acc=0.9948
# Epoch 337/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2184 acc=0.9948
# Epoch 338/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2195 acc=0.9930
# Epoch 339/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2190 acc=0.9913
# Epoch 340/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2187 acc=0.9930
# Epoch 341/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2196 acc=0.9896
# Epoch 342/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2196 acc=0.9930
# Epoch 343/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2252 acc=0.9861
# Epoch 344/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2306 acc=0.9843
# Epoch 345/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2260 acc=0.9878
# Epoch 346/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2203 acc=0.9930
# Epoch 347/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2200 acc=0.9930
# Epoch 348/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2207 acc=0.9913
# Epoch 349/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2223 acc=0.9896
# Epoch 350/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.2253 acc=0.9861
# Epoch 351/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.2223 acc=0.9896
# Epoch 352/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.2244 acc=0.9878
# Epoch 353/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2213 acc=0.9896
# Epoch 354/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2215 acc=0.9913
# Epoch 355/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2203 acc=0.9930
# Epoch 356/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2214 acc=0.9930
# Epoch 357/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2206 acc=0.9930
# Epoch 358/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2183 acc=0.9930
# Epoch 359/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2210 acc=0.9913
# Epoch 360/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2183 acc=0.9948
# Epoch 361/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2165 acc=0.9948
# Epoch 362/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2179 acc=0.9930
# Epoch 363/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2177 acc=0.9930
# Epoch 364/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2176 acc=0.9948
# Epoch 365/500 | train_loss=0.2028 acc=0.9996 | val_loss=0.2191 acc=0.9930
# Epoch 366/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2182 acc=0.9948
# Epoch 367/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2168 acc=0.9948
# Epoch 368/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2173 acc=0.9948
# Epoch 369/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2207 acc=0.9913
# Epoch 370/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.2200 acc=0.9930
# Epoch 371/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2179 acc=0.9948
# Epoch 372/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2179 acc=0.9948
# Epoch 373/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2176 acc=0.9948
# Epoch 374/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2187 acc=0.9948
# Epoch 375/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2285 acc=0.9861
# Epoch 376/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2204 acc=0.9913
# Epoch 377/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2232 acc=0.9913
# Epoch 378/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2231 acc=0.9913
# Epoch 379/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2219 acc=0.9913
# Epoch 380/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2239 acc=0.9913
# Epoch 381/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2209 acc=0.9913
# Epoch 382/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2223 acc=0.9913
# Epoch 383/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2210 acc=0.9913
# Epoch 384/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2207 acc=0.9930
# Epoch 385/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2223 acc=0.9896
# Epoch 386/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2212 acc=0.9913
# Epoch 387/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2209 acc=0.9913
# Epoch 388/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2200 acc=0.9913
# Epoch 389/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2209 acc=0.9913
# Epoch 390/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2193 acc=0.9948
# Epoch 391/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2217 acc=0.9896
# Epoch 392/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2195 acc=0.9913
# Epoch 393/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2196 acc=0.9930
# Epoch 394/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2205 acc=0.9913
# Epoch 395/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2205 acc=0.9930
# Epoch 396/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2185 acc=0.9948
# Epoch 397/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2203 acc=0.9930
# Epoch 398/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2200 acc=0.9930
# Epoch 399/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2226 acc=0.9930
# Epoch 400/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2191 acc=0.9930
# Epoch 401/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2250 acc=0.9896
# Epoch 402/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2210 acc=0.9913
# Epoch 403/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2217 acc=0.9913
# Epoch 404/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2209 acc=0.9913
# Epoch 405/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2216 acc=0.9913
# Epoch 406/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2213 acc=0.9930
# Epoch 407/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2227 acc=0.9913
# Epoch 408/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2230 acc=0.9896
# Epoch 409/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.2303 acc=0.9843
# Epoch 410/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2266 acc=0.9878
# Epoch 411/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2249 acc=0.9878
# Epoch 412/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2264 acc=0.9896
# Epoch 413/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2265 acc=0.9861
# Epoch 414/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2229 acc=0.9913
# Epoch 415/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2219 acc=0.9896
# Epoch 416/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.2204 acc=0.9896
# Epoch 417/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2194 acc=0.9913
# Epoch 418/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2207 acc=0.9896
# Epoch 419/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2214 acc=0.9896
# Epoch 420/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2214 acc=0.9913
# Epoch 421/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2228 acc=0.9930
# Epoch 422/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2219 acc=0.9896
# Epoch 423/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2227 acc=0.9896
# Epoch 424/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2208 acc=0.9930
# Epoch 425/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2206 acc=0.9930
# Epoch 426/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2250 acc=0.9878
# Epoch 427/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2244 acc=0.9913
# Epoch 428/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2213 acc=0.9913
# Epoch 429/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2216 acc=0.9913
# Epoch 430/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2206 acc=0.9913
# Epoch 431/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2207 acc=0.9930
# Epoch 432/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2209 acc=0.9913
# Epoch 433/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2204 acc=0.9913
# Epoch 434/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2225 acc=0.9913
# Epoch 435/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2213 acc=0.9930
# Epoch 436/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2202 acc=0.9930
# Epoch 437/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2220 acc=0.9913
# Epoch 438/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2207 acc=0.9913
# Epoch 439/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2232 acc=0.9896
# Epoch 440/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2199 acc=0.9930
# Epoch 441/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2208 acc=0.9913
# Epoch 442/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2195 acc=0.9913
# Epoch 443/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2196 acc=0.9930
# Epoch 444/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2208 acc=0.9913
# Epoch 445/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2201 acc=0.9930
# Epoch 446/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2203 acc=0.9913
# Epoch 447/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2218 acc=0.9913
# Epoch 448/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2205 acc=0.9913
# Epoch 449/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2191 acc=0.9930
# Epoch 450/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2222 acc=0.9913
# Epoch 451/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2201 acc=0.9930
# Epoch 452/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2204 acc=0.9930
# Epoch 453/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2213 acc=0.9913
# Epoch 454/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2207 acc=0.9913
# Epoch 455/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2200 acc=0.9930
# Epoch 456/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2207 acc=0.9930
# Epoch 457/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2207 acc=0.9913
# Epoch 458/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2217 acc=0.9913
# Epoch 459/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2237 acc=0.9913
# Epoch 460/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2227 acc=0.9913
# Epoch 461/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2245 acc=0.9896
# Epoch 462/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2225 acc=0.9913
# Epoch 463/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2233 acc=0.9896
# Epoch 464/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2216 acc=0.9913
# Epoch 465/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2245 acc=0.9896
# Epoch 466/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2218 acc=0.9930
# Epoch 467/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2231 acc=0.9896
# Epoch 468/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2216 acc=0.9930
# Epoch 469/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2248 acc=0.9896
# Epoch 470/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2222 acc=0.9913
# Epoch 471/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2233 acc=0.9913
# Epoch 472/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2212 acc=0.9896
# Epoch 473/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2209 acc=0.9913
# Epoch 474/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2227 acc=0.9913
# Epoch 475/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2226 acc=0.9913
# Epoch 476/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2227 acc=0.9913
# Epoch 477/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2219 acc=0.9930
# Epoch 478/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2218 acc=0.9913
# Epoch 479/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2240 acc=0.9896
# Epoch 480/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2223 acc=0.9913
# Epoch 481/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2223 acc=0.9930
# Epoch 482/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2231 acc=0.9913
# Epoch 483/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2225 acc=0.9896
# Epoch 484/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2225 acc=0.9913
# Epoch 485/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2206 acc=0.9913
# Epoch 486/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2213 acc=0.9913
# Epoch 487/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2229 acc=0.9913
# Epoch 488/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2222 acc=0.9913
# Epoch 489/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2212 acc=0.9930
# Epoch 490/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2224 acc=0.9896
# Epoch 491/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2215 acc=0.9896
# Epoch 492/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2220 acc=0.9913
# Epoch 493/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2235 acc=0.9896
# Epoch 494/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2239 acc=0.9896
# Epoch 495/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2222 acc=0.9913
# Epoch 496/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2245 acc=0.9896
# Epoch 497/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2231 acc=0.9913
# Epoch 498/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2223 acc=0.9913
# Epoch 499/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2212 acc=0.9930
# Epoch 500/500 | train_loss=0.2015 acc=1.0000 | val_loss=0.2224 acc=0.9913
# Best val loss: 0.2131. Saved to: best_MobileNetV2_Loss_brain_tumor.pt
# /tmp/ipykernel_1809/3782923474.py:147: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(best_path, map_location=device)
# Test classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     1.0000    0.4000    0.5714       100
# meningioma_tumor     0.7170    0.9913    0.8321       115
#         no_tumor     0.8217    1.0000    0.9021       129
#  pituitary_tumor     1.0000    0.8378    0.9118        74
#
#         accuracy                         0.8254       418
#        macro avg     0.8847    0.8073    0.8044       418
#     weighted avg     0.8671    0.8254    0.8054       418
#
#
# Confusion matrix:
# [[ 40  39  21   0]
#  [  0 114   1   0]
#  [  0   0 129   0]
#  [  0   6   6  62]]
