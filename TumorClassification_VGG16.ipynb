# %%
#Setting up paths for data
data_root = "/home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data/Brain-Tumor-Classification" 

tr_base  = data_root+"/Training"
te_base  = data_root+"/Testing"

# %%
#Setting up Transforms 
from pathlib import Path
from torch.utils.data import DataLoader, Subset, WeightedRandomSampler # remember subset when you divide into training and validation
from torchvision import datasets, transforms, utils, models # add models when you import pretrained models for transfer learning
import os
import torch
import numpy as np

IMG_SIZE = 512

def zscore(x):  # MRI-friendly
    return (x - x.mean()) / (x.std() + 1e-8)

train_tf = transforms.Compose([
    transforms.Lambda(lambda im: im.convert('L')),                 # use 'RGB' if truly 3-ch
    transforms.Grayscale(num_output_channels=3), 
    transforms.Resize((IMG_SIZE, IMG_SIZE), antialias=True),
    transforms.RandomAffine(degrees=10, translate=(0.02,0.02), scale=(0.95,1.05)),
    transforms.RandomApply([transforms.GaussianBlur(3, (0.1, 1.0))], p=0.2),
    transforms.ColorJitter(brightness=0.10, contrast=0.10),
    transforms.ToTensor(),
    #transforms.Lambda(zscore),
])

eval_tf = transforms.Compose([
    transforms.Lambda(lambda im: im.convert('L')),
    transforms.Grayscale(num_output_channels=3), 
    transforms.Resize((IMG_SIZE, IMG_SIZE), antialias=True),
    transforms.ToTensor(),
    #transforms.Lambda(zscore),
])

# %%
trainset=datasets.ImageFolder(tr_base, transform=train_tf)
valset = datasets.ImageFolder(tr_base, transform=eval_tf)
testset=datasets.ImageFolder(te_base, transform=eval_tf)


print(testset.classes)
print(trainset.classes)
print(valset.classes)

val_fraction=0.2

idxs = list(range(len(valset)))
rng = np.random.default_rng(42)
rng.shuffle(idxs)

n_val = int(len(idxs) * val_fraction)
val_idx = idxs[:n_val]
train_idx = idxs[n_val:]

trainset = Subset(trainset, train_idx)
valset   = Subset(valset,   val_idx)

class_names = datasets.ImageFolder(tr_base).classes
# Out:
# ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
# ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
# ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

# %%
def get_targets_from_dataset(ds) -> np.ndarray:
    """Return class indices for ImageFolder or Subset(ImageFolder)."""
    if isinstance(ds, Subset):
        base, idxs = ds.dataset, ds.indices
        if hasattr(base, "targets"):
            return np.asarray(base.targets, dtype=int)[idxs]
        return np.asarray([base.samples[i][1] for i in idxs], dtype=int)
    # ImageFolder
    if hasattr(ds, "targets"):
        return np.asarray(ds.targets, dtype=int)
    return np.asarray([y for _, y in ds.samples], dtype=int)

# %%
# assume you already created trainset (ImageFolder or Subset(ImageFolder))
targets = get_targets_from_dataset(trainset)              # shape [N]
num_classes = int(targets.max() + 1)

# inverse-frequency class weights (simple & effective)
class_counts  = np.bincount(targets, minlength=num_classes).astype(float)
class_weights = 1.0 / np.maximum(class_counts, 1.0)      # avoid div/0
sample_weights = class_weights[targets]                   # per-sample weight

sampler = WeightedRandomSampler(
    weights=torch.as_tensor(sample_weights, dtype=torch.double),
    num_samples=len(sample_weights),   # one epoch ~= dataset size
    replacement=True                   # allows oversampling of minority class
)

BATCH = 4
WORKERS = 4


train_loader = DataLoader(
    trainset,
    batch_size=BATCH,
    shuffle=False,
    sampler=sampler,
    num_workers=WORKERS,
    pin_memory=True,
    drop_last=True,                    # optional: keeps batch size stable
)

# validation/test loaders stay standard (no sampler)
val_loader = DataLoader(valset, batch_size=64, shuffle=False, num_workers=WORKERS, pin_memory=True)

# %%
import torch.nn as nn
from torchvision import models

def build_model(n_classes, freeze_backbone=False):
    """
    Build a Swin Transformer Base model pretrained on ImageNet-1K,
    replace classification head for custom number of classes,
    and optionally freeze backbone layers.
    """
    # 1️⃣ Load pretrained Swin Transformer Base
    model = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)

    # 2️⃣ Replace classifier head
    in_feats = model.classifier[-1].in_features
    model.classifier[-1] = nn.Linear(in_feats, n_classes)
    if freeze_backbone:
        for p in model.features.parameters():
            p.requires_grad = False
    return model


model = build_model(n_classes=4, freeze_backbone=False)
print(model)

# Verify output
import torch
x = torch.randn(2, 3, 512, 512)
out = model(x)
print(out.shape)  # → [2, 4]
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /home/jovyan/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:01<00:00, 316MB/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=4, bias=True)
#   )
# )
# torch.Size([2, 4])

# %%
# ----------------------------
# 3) Training utilities
# ----------------------------
class EarlyStopper:
    def __init__(self, patience=8, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best = None
        self.count = 0

    def step(self, metric):
        if self.best is None or metric > self.best + self.min_delta:
            self.best = metric
            self.count = 0
            return False  # do not stop

# %%
import contextlib
import torch
import torch.nn.functional as F

def epoch_run(model, loader, criterion, device, train: bool, use_amp: bool,
              optimizer=None, scaler=None):
    assert (train and optimizer is not None and scaler is not None) or (not train)

    model.train() if train else model.eval()

    total = 0
    running_loss = 0.0
    correct = 0

    # no graph during evaluation
    cm = contextlib.nullcontext() if train else torch.no_grad()

    with cm:
        for xb, yb in loader:
            xb = xb.to(device, non_blocking=True)
            yb = yb.to(device, non_blocking=True)

            with torch.amp.autocast('cuda', enabled=(use_amp and device.type == 'cuda')):
                logits = model(xb)
                loss = criterion(logits, yb)

            if train:
                optimizer.zero_grad(set_to_none=True)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

            running_loss += loss.detach().float().item() * xb.size(0)
            pred = logits.argmax(1)
            correct += (pred == yb).sum().item()
            total += yb.size(0)

    return running_loss / total, correct / total

# %%
def set_seed(seed=42):
    random.seed(seed); np.random.seed(seed); torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

def get_device():
    return torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def to_device(batch, device):
    x, y = batch
    return x.to(device, non_blocking=True), y.to(device, non_blocking=True)

# %%
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import Counter
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from torch import amp
import json

seed=2025
set_seed(seed)
device = get_device()
print("Device:", device)

DATA_ROOT = data_root 
BATCH = 32
EPOCHS = 500
LR = 3e-4
FREEZE_BACKBONE = False  # set True to train only the last layer first

#trainset, valset, testset, class_names = build_datasets(DATA_ROOT, img_size=224, val_fraction=0.15)
print("Classes:", class_names)

scaler = amp.GradScaler('cuda', enabled=(device.type=='cuda'))

train_loader = DataLoader(trainset,batch_size=BATCH,sampler=sampler,num_workers=WORKERS,pin_memory=True)                    # optional: keeps batch size stable)
val_loader = DataLoader(valset, batch_size=BATCH*2, shuffle=False,num_workers=WORKERS, pin_memory=True, drop_last=False)
test_loader = DataLoader(testset, batch_size=BATCH*2, shuffle=False,num_workers=WORKERS, pin_memory=True, drop_last=False)   

print("Train uses sampler:", train_loader.sampler.__class__.__name__)
print("Val uses sampler:  ", val_loader.sampler.__class__.__name__)
print("Test uses sampler: ", test_loader.sampler.__class__.__name__)

model = build_model(n_classes=len(class_names), freeze_backbone=FREEZE_BACKBONE)
model.to(device)

#model = CNN512x3(num_classes=4, in_ch=3, dropout=0.5).to(device)
#criterion = nn.CrossEntropyLoss()  
criterion = torch.nn.CrossEntropyLoss(label_smoothing=0.05)
#criterion = FocalLoss(
#    gamma=1.5,    # 1.0 = CE; 1.5–2.0 is often best
#    reduction='mean'
#)
optimizer = torch.optim.AdamW(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

history = {
    "train_loss": [],
    "val_loss":   [],
    "train_acc":  [],
    "val_acc":    [],
}


best_loss, best_acc, best_path, best_path_acc = 1000, 0.0, "best_VGG16_Loss_brain_tumor.pt", "best_VGG16_Acc_brain_tumor.pt"
stopper = EarlyStopper(patience=7, min_delta=1e-4)

for epoch in range(1, EPOCHS+1):
    #train_loss, train_acc = epoch_run(model, train_loader, criterion, device, train=True, use_amp=True)
    #val_loss,   val_acc   = epoch_run(model, val_loader,   criterion, device, train=False, use_amp=True)
    
    train_loss, train_acc = epoch_run(model, train_loader, criterion, device, train=True, use_amp=True, optimizer=optimizer, scaler=scaler)
    val_loss,   val_acc   = epoch_run(model, val_loader,   criterion, device, train=False, use_amp=True)
    #scheduler.step(val_loss)
    scheduler.step()
    print(f"Epoch {epoch:02d}/{EPOCHS} | "
          f"train_loss={train_loss:.4f} acc={train_acc:.4f} | "
          f"val_loss={val_loss:.4f} acc={val_acc:.4f}")

    # log
    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)

    #Save model
    if val_loss < best_loss:
        best_loss = val_loss
        torch.save({"model": model.state_dict(),
                    "classes": class_names}, best_path)
        
    if val_acc > best_acc:
        best_acc = val_acc
        torch.save({"model": model.state_dict(),
                    "classes": class_names}, best_path_acc)



    if stopper.step(val_acc):
        print("Early stopping triggered.")
        break


print(f"Best val loss: {best_loss:.4f}. Saved to: {best_path}")

with open("history_VGG16.json", "w") as f:
    json.dump(history, f)


# ---- after training: plots ----
epochs = range(1, len(history["train_loss"]) + 1)

plt.figure()
plt.plot(epochs, history["train_loss"], label="Train loss")
plt.plot(epochs, history["val_loss"],   label="Val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# (optional) accuracy plot
plt.figure()
plt.plot(epochs, history["train_acc"], label="Train acc")
plt.plot(epochs, history["val_acc"],   label="Val acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# ----------------------------
# Evaluation on test (if available)
# ----------------------------
if test_loader is not None:
    ckpt = torch.load(best_path, map_location=device)
    model.load_state_dict(ckpt["model"])
    model.eval()
    all_preds, all_tgts = [], []
    with torch.no_grad():
        for xb, yb in test_loader:
            xb, yb = to_device((xb, yb), device)
            logits = model(xb)
            all_preds.append(logits.argmax(1).cpu())
            all_tgts.append(yb.cpu())


    y_pred = torch.cat(all_preds).numpy()
    y_true = torch.cat(all_tgts).numpy()
    print("\nTest classification report:")
    print(classification_report(y_true, y_pred, target_names= class_names, digits=4))
    print("\nConfusion matrix:")
    print(confusion_matrix(y_true, y_pred))
# Out:
# Device: cuda
# Classes: ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
# Train uses sampler: WeightedRandomSampler
# Val uses sampler:   SequentialSampler
# Test uses sampler:  SequentialSampler
# Epoch 01/500 | train_loss=0.9613 acc=0.6340 | val_loss=0.6580 acc=0.7948
# Epoch 02/500 | train_loss=0.5924 acc=0.8285 | val_loss=0.6101 acc=0.8330
# Epoch 03/500 | train_loss=0.5022 acc=0.8667 | val_loss=0.4862 acc=0.8887
# Epoch 04/500 | train_loss=0.4943 acc=0.8736 | val_loss=0.5374 acc=0.8348
# Epoch 05/500 | train_loss=0.4271 acc=0.9123 | val_loss=0.6233 acc=0.8470
# Epoch 06/500 | train_loss=0.4162 acc=0.9162 | val_loss=0.4691 acc=0.8817
# Epoch 07/500 | train_loss=0.3523 acc=0.9388 | val_loss=0.4393 acc=0.9078
# Epoch 08/500 | train_loss=0.3236 acc=0.9518 | val_loss=0.3610 acc=0.9270
# Epoch 42/500 | train_loss=0.2047 acc=1.0000 | val_loss=0.2610 acc=0.9704
# Epoch 43/500 | train_loss=0.2044 acc=1.0000 | val_loss=0.2573 acc=0.9722
# Epoch 44/500 | train_loss=0.2045 acc=1.0000 | val_loss=0.2592 acc=0.9722
# Epoch 45/500 | train_loss=0.2042 acc=1.0000 | val_loss=0.2574 acc=0.9757
# Epoch 46/500 | train_loss=0.2041 acc=1.0000 | val_loss=0.2527 acc=0.9757
# Epoch 47/500 | train_loss=0.2041 acc=1.0000 | val_loss=0.2462 acc=0.9809
# Epoch 48/500 | train_loss=0.2039 acc=1.0000 | val_loss=0.2475 acc=0.9791
# Epoch 49/500 | train_loss=0.2039 acc=1.0000 | val_loss=0.2581 acc=0.9739
# Epoch 50/500 | train_loss=0.2038 acc=1.0000 | val_loss=0.2510 acc=0.9791
# Epoch 51/500 | train_loss=0.2038 acc=1.0000 | val_loss=0.2594 acc=0.9739
# Epoch 52/500 | train_loss=0.2037 acc=1.0000 | val_loss=0.2528 acc=0.9774
# Epoch 53/500 | train_loss=0.2036 acc=1.0000 | val_loss=0.2611 acc=0.9704
# Epoch 54/500 | train_loss=0.2035 acc=1.0000 | val_loss=0.2591 acc=0.9757
# Epoch 55/500 | train_loss=0.2035 acc=1.0000 | val_loss=0.2626 acc=0.9704
# Epoch 56/500 | train_loss=0.2035 acc=1.0000 | val_loss=0.2565 acc=0.9757
# Epoch 57/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.2572 acc=0.9722
# Epoch 58/500 | train_loss=0.2034 acc=1.0000 | val_loss=0.2593 acc=0.9722
# Epoch 59/500 | train_loss=0.2034 acc=1.0000 | val_loss=0.2510 acc=0.9774
# Epoch 60/500 | train_loss=0.2034 acc=1.0000 | val_loss=0.2636 acc=0.9757
# Epoch 61/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.2559 acc=0.9774
# Epoch 62/500 | train_loss=0.2033 acc=1.0000 | val_loss=0.2574 acc=0.9757
# Epoch 63/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.2517 acc=0.9809
# Epoch 64/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.2540 acc=0.9739
# Epoch 65/500 | train_loss=0.2031 acc=1.0000 | val_loss=0.2543 acc=0.9739
# Epoch 66/500 | train_loss=0.2030 acc=1.0000 | val_loss=0.2590 acc=0.9739
# Epoch 67/500 | train_loss=0.2030 acc=1.0000 | val_loss=0.2597 acc=0.9739
# Epoch 68/500 | train_loss=0.2030 acc=1.0000 | val_loss=0.2652 acc=0.9704
# Epoch 69/500 | train_loss=0.2030 acc=1.0000 | val_loss=0.2586 acc=0.9739
# Epoch 70/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.2644 acc=0.9774
# Epoch 71/500 | train_loss=0.5370 acc=0.8550 | val_loss=1.3207 acc=0.3687
# Epoch 72/500 | train_loss=1.5888 acc=0.3530 | val_loss=1.2544 acc=0.4330
# Epoch 73/500 | train_loss=1.1940 acc=0.4954 | val_loss=1.0086 acc=0.6017
# Epoch 74/500 | train_loss=0.9987 acc=0.6140 | val_loss=0.8564 acc=0.6643
# Epoch 75/500 | train_loss=0.8165 acc=0.7052 | val_loss=0.7427 acc=0.7270
# Epoch 76/500 | train_loss=0.7351 acc=0.7534 | val_loss=0.7834 acc=0.7304
# Epoch 77/500 | train_loss=0.6936 acc=0.7742 | val_loss=0.7146 acc=0.7548
# Epoch 78/500 | train_loss=0.6225 acc=0.8168 | val_loss=0.6313 acc=0.7965
# Epoch 208/500 | train_loss=0.2069 acc=0.9996 | val_loss=0.3839 acc=0.9217
# Epoch 209/500 | train_loss=0.2059 acc=1.0000 | val_loss=0.3761 acc=0.9357
# Epoch 210/500 | train_loss=0.2046 acc=1.0000 | val_loss=0.3714 acc=0.9357
# Epoch 211/500 | train_loss=0.2043 acc=1.0000 | val_loss=0.3512 acc=0.9322
# Epoch 212/500 | train_loss=0.2050 acc=1.0000 | val_loss=0.3590 acc=0.9426
# Epoch 213/500 | train_loss=0.2137 acc=0.9965 | val_loss=0.4073 acc=0.9200
# Epoch 214/500 | train_loss=0.2302 acc=0.9896 | val_loss=0.4880 acc=0.9009
# Epoch 215/500 | train_loss=0.2356 acc=0.9896 | val_loss=0.4045 acc=0.9200
# Epoch 216/500 | train_loss=0.2215 acc=0.9939 | val_loss=0.3811 acc=0.9322
# Epoch 217/500 | train_loss=0.2089 acc=0.9996 | val_loss=0.3782 acc=0.9339
# Epoch 218/500 | train_loss=0.2060 acc=1.0000 | val_loss=0.3861 acc=0.9304
# Epoch 219/500 | train_loss=0.2051 acc=1.0000 | val_loss=0.3935 acc=0.9322
# Epoch 220/500 | train_loss=0.2062 acc=1.0000 | val_loss=0.3843 acc=0.9252
# Epoch 221/500 | train_loss=0.2070 acc=0.9991 | val_loss=0.3596 acc=0.9287
# Epoch 222/500 | train_loss=0.2054 acc=0.9996 | val_loss=0.3675 acc=0.9322
# Epoch 223/500 | train_loss=0.2048 acc=1.0000 | val_loss=0.3603 acc=0.9357
# Epoch 224/500 | train_loss=0.2050 acc=0.9996 | val_loss=0.3532 acc=0.9339
# Epoch 225/500 | train_loss=0.2071 acc=0.9987 | val_loss=0.4224 acc=0.9183
# Epoch 226/500 | train_loss=0.2178 acc=0.9944 | val_loss=0.4111 acc=0.9148
# Epoch 227/500 | train_loss=0.2174 acc=0.9952 | val_loss=0.4002 acc=0.9148
# Epoch 228/500 | train_loss=0.2082 acc=0.9991 | val_loss=0.3854 acc=0.9235
# Epoch 229/500 | train_loss=0.2057 acc=1.0000 | val_loss=0.3674 acc=0.9374
# Epoch 230/500 | train_loss=0.2050 acc=1.0000 | val_loss=0.3570 acc=0.9357
# Epoch 231/500 | train_loss=0.2045 acc=1.0000 | val_loss=0.3621 acc=0.9374
# Epoch 232/500 | train_loss=0.2041 acc=1.0000 | val_loss=0.3607 acc=0.9391
# Epoch 233/500 | train_loss=0.2039 acc=1.0000 | val_loss=0.3627 acc=0.9391
# Epoch 234/500 | train_loss=0.2035 acc=1.0000 | val_loss=0.3679 acc=0.9374
# Epoch 235/500 | train_loss=0.2038 acc=1.0000 | val_loss=0.3605 acc=0.9409
# Epoch 236/500 | train_loss=0.2038 acc=1.0000 | val_loss=0.3712 acc=0.9357
# Epoch 237/500 | train_loss=0.2036 acc=1.0000 | val_loss=0.3689 acc=0.9339
# Epoch 238/500 | train_loss=0.2033 acc=1.0000 | val_loss=0.3743 acc=0.9322
# Epoch 239/500 | train_loss=0.2038 acc=1.0000 | val_loss=0.3800 acc=0.9270
# Epoch 240/500 | train_loss=0.2038 acc=1.0000 | val_loss=0.3742 acc=0.9357
# Epoch 241/500 | train_loss=0.2036 acc=1.0000 | val_loss=0.3650 acc=0.9374
# Epoch 242/500 | train_loss=0.2050 acc=0.9996 | val_loss=0.3878 acc=0.9270
# Epoch 243/500 | train_loss=0.2040 acc=0.9996 | val_loss=0.3987 acc=0.9339
# Epoch 244/500 | train_loss=0.2275 acc=0.9900 | val_loss=0.4089 acc=0.9165
# Epoch 245/500 | train_loss=0.2202 acc=0.9935 | val_loss=0.4595 acc=0.9078
# Epoch 246/500 | train_loss=0.2220 acc=0.9931 | val_loss=0.3912 acc=0.9270
# Epoch 247/500 | train_loss=0.2198 acc=0.9931 | val_loss=0.4265 acc=0.9113
# Epoch 248/500 | train_loss=0.2098 acc=1.0000 | val_loss=0.4042 acc=0.9270
# Epoch 249/500 | train_loss=0.2066 acc=0.9996 | val_loss=0.3842 acc=0.9304
# Epoch 250/500 | train_loss=0.2068 acc=0.9991 | val_loss=0.3854 acc=0.9357
# Epoch 251/500 | train_loss=0.2060 acc=1.0000 | val_loss=0.3786 acc=0.9339
# Epoch 252/500 | train_loss=0.2049 acc=1.0000 | val_loss=0.3656 acc=0.9374
# Epoch 253/500 | train_loss=0.2041 acc=1.0000 | val_loss=0.3804 acc=0.9304
# Epoch 254/500 | train_loss=0.2045 acc=1.0000 | val_loss=0.3656 acc=0.9409
# Epoch 255/500 | train_loss=0.2040 acc=0.9996 | val_loss=0.3735 acc=0.9339
# Epoch 256/500 | train_loss=0.2039 acc=1.0000 | val_loss=0.3574 acc=0.9374
# Epoch 257/500 | train_loss=0.2040 acc=1.0000 | val_loss=0.3721 acc=0.9409
# Epoch 258/500 | train_loss=0.2034 acc=1.0000 | val_loss=0.3668 acc=0.9339
# Epoch 259/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.3626 acc=0.9374
# Epoch 260/500 | train_loss=0.2031 acc=1.0000 | val_loss=0.3607 acc=0.9374
# Epoch 261/500 | train_loss=0.2030 acc=1.0000 | val_loss=0.3583 acc=0.9426
# Epoch 262/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.3511 acc=0.9426
# Epoch 263/500 | train_loss=0.2029 acc=1.0000 | val_loss=0.3555 acc=0.9443
# Epoch 264/500 | train_loss=0.2030 acc=1.0000 | val_loss=0.3534 acc=0.9391
# Epoch 265/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.3570 acc=0.9409
# Epoch 266/500 | train_loss=0.2030 acc=1.0000 | val_loss=0.3617 acc=0.9391
# Epoch 267/500 | train_loss=0.2029 acc=1.0000 | val_loss=0.3689 acc=0.9304
# Epoch 268/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.3615 acc=0.9374
# Epoch 269/500 | train_loss=0.2030 acc=1.0000 | val_loss=0.3629 acc=0.9391
# Epoch 270/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.3630 acc=0.9374
# Epoch 271/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.3625 acc=0.9391
# Epoch 272/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.3675 acc=0.9426
# Epoch 273/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.3688 acc=0.9357
# Epoch 274/500 | train_loss=0.2031 acc=1.0000 | val_loss=0.3674 acc=0.9409
# Epoch 275/500 | train_loss=0.2027 acc=1.0000 | val_loss=0.3557 acc=0.9374
# Epoch 276/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.3618 acc=0.9426
# Epoch 277/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.3632 acc=0.9443
# Epoch 278/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.3592 acc=0.9357
# Epoch 279/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.3641 acc=0.9426
# Epoch 280/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3619 acc=0.9374
# Epoch 281/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.3625 acc=0.9322
# Epoch 282/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.3628 acc=0.9339
# Epoch 283/500 | train_loss=0.2122 acc=0.9965 | val_loss=0.4461 acc=0.9148
# Epoch 284/500 | train_loss=0.2142 acc=0.9970 | val_loss=0.4260 acc=0.9165
# Epoch 285/500 | train_loss=0.2144 acc=0.9957 | val_loss=0.3897 acc=0.9217
# Epoch 286/500 | train_loss=0.2119 acc=0.9974 | val_loss=0.4056 acc=0.9270
# Epoch 287/500 | train_loss=0.2054 acc=1.0000 | val_loss=0.3710 acc=0.9426
# Epoch 288/500 | train_loss=0.2055 acc=0.9987 | val_loss=0.3906 acc=0.9270
# Epoch 289/500 | train_loss=0.2043 acc=1.0000 | val_loss=0.3806 acc=0.9339
# Epoch 290/500 | train_loss=0.2038 acc=1.0000 | val_loss=0.3512 acc=0.9443
# Epoch 291/500 | train_loss=0.2031 acc=1.0000 | val_loss=0.3567 acc=0.9443
# Epoch 292/500 | train_loss=0.2030 acc=1.0000 | val_loss=0.3629 acc=0.9374
# Epoch 293/500 | train_loss=0.2033 acc=1.0000 | val_loss=0.3600 acc=0.9391
# Epoch 294/500 | train_loss=0.2031 acc=1.0000 | val_loss=0.3594 acc=0.9391
# Epoch 295/500 | train_loss=0.2032 acc=1.0000 | val_loss=0.3406 acc=0.9426
# Epoch 296/500 | train_loss=0.2028 acc=1.0000 | val_loss=0.3481 acc=0.9426
# Epoch 297/500 | train_loss=0.2029 acc=1.0000 | val_loss=0.3451 acc=0.9426
# Epoch 298/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.3403 acc=0.9443
# Epoch 299/500 | train_loss=0.2026 acc=1.0000 | val_loss=0.3431 acc=0.9391
# Epoch 300/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.3498 acc=0.9374
# Epoch 301/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.3443 acc=0.9409
# Epoch 302/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3353 acc=0.9374
# Epoch 303/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3463 acc=0.9409
# Epoch 304/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.3518 acc=0.9426
# Epoch 305/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3625 acc=0.9426
# Epoch 306/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3490 acc=0.9461
# Epoch 307/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3488 acc=0.9409
# Epoch 308/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3497 acc=0.9374
# Epoch 309/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3645 acc=0.9322
# Epoch 310/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3594 acc=0.9339
# Epoch 311/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3523 acc=0.9409
# Epoch 312/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3668 acc=0.9339
# Epoch 313/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.3773 acc=0.9304
# Epoch 314/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3726 acc=0.9304
# Epoch 315/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3576 acc=0.9322
# Epoch 316/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3584 acc=0.9357
# Epoch 317/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3696 acc=0.9322
# Epoch 318/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3697 acc=0.9304
# Epoch 319/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3644 acc=0.9304
# Epoch 320/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3626 acc=0.9304
# Epoch 321/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3656 acc=0.9287
# Epoch 322/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3591 acc=0.9322
# Epoch 323/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3703 acc=0.9322
# Epoch 324/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3607 acc=0.9409
# Epoch 325/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3599 acc=0.9357
# Epoch 326/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3462 acc=0.9443
# Epoch 327/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3506 acc=0.9374
# Epoch 328/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3522 acc=0.9374
# Epoch 329/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3463 acc=0.9461
# Epoch 330/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3544 acc=0.9409
# Epoch 331/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3460 acc=0.9443
# Epoch 332/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3396 acc=0.9461
# Epoch 333/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3424 acc=0.9409
# Epoch 334/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3527 acc=0.9409
# Epoch 335/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3780 acc=0.9322
# Epoch 336/500 | train_loss=0.2101 acc=0.9961 | val_loss=0.3525 acc=0.9357
# Epoch 337/500 | train_loss=0.2051 acc=0.9996 | val_loss=0.3627 acc=0.9426
# Epoch 338/500 | train_loss=0.2029 acc=1.0000 | val_loss=0.3580 acc=0.9409
# Epoch 339/500 | train_loss=0.2031 acc=1.0000 | val_loss=0.3624 acc=0.9409
# Epoch 340/500 | train_loss=0.2025 acc=1.0000 | val_loss=0.3549 acc=0.9374
# Epoch 341/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3584 acc=0.9409
# Epoch 342/500 | train_loss=0.2024 acc=1.0000 | val_loss=0.3531 acc=0.9426
# Epoch 343/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3528 acc=0.9409
# Epoch 344/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3526 acc=0.9409
# Epoch 345/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3521 acc=0.9357
# Epoch 346/500 | train_loss=0.2023 acc=1.0000 | val_loss=0.3443 acc=0.9461
# Epoch 347/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3521 acc=0.9443
# Epoch 348/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3678 acc=0.9409
# Epoch 349/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3571 acc=0.9391
# Epoch 350/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3607 acc=0.9374
# Epoch 351/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3633 acc=0.9391
# Epoch 352/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3629 acc=0.9391
# Epoch 353/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3666 acc=0.9374
# Epoch 354/500 | train_loss=0.2021 acc=1.0000 | val_loss=0.3533 acc=0.9409
# Epoch 355/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3590 acc=0.9409
# Epoch 356/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3702 acc=0.9357
# Epoch 357/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3595 acc=0.9339
# Epoch 358/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3580 acc=0.9322
# Epoch 359/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3545 acc=0.9322
# Epoch 360/500 | train_loss=0.2022 acc=1.0000 | val_loss=0.3600 acc=0.9357
# Epoch 361/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3583 acc=0.9339
# Epoch 362/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3588 acc=0.9391
# Epoch 363/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3598 acc=0.9357
# Epoch 364/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3656 acc=0.9339
# Epoch 365/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3596 acc=0.9357
# Epoch 366/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3592 acc=0.9322
# Epoch 367/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3674 acc=0.9357
# Epoch 368/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3746 acc=0.9304
# Epoch 369/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3687 acc=0.9287
# Epoch 370/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3708 acc=0.9357
# Epoch 371/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3641 acc=0.9409
# Epoch 372/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3644 acc=0.9339
# Epoch 373/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3555 acc=0.9409
# Epoch 374/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3610 acc=0.9304
# Epoch 375/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3610 acc=0.9270
# Epoch 376/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3570 acc=0.9374
# Epoch 377/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3557 acc=0.9357
# Epoch 378/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3539 acc=0.9391
# Epoch 379/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3678 acc=0.9339
# Epoch 380/500 | train_loss=0.2020 acc=1.0000 | val_loss=0.3637 acc=0.9391
# Epoch 381/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3573 acc=0.9409
# Epoch 382/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3634 acc=0.9374
# Epoch 383/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3567 acc=0.9461
# Epoch 384/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3520 acc=0.9409
# Epoch 385/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3563 acc=0.9391
# Epoch 386/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3556 acc=0.9357
# Epoch 387/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3578 acc=0.9426
# Epoch 388/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3686 acc=0.9339
# Epoch 389/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3623 acc=0.9426
# Epoch 390/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.3524 acc=0.9357
# Epoch 391/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3618 acc=0.9357
# Epoch 392/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3683 acc=0.9357
# Epoch 393/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3706 acc=0.9322
# Epoch 394/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3728 acc=0.9339
# Epoch 395/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3695 acc=0.9391
# Epoch 396/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3672 acc=0.9357
# Epoch 397/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3689 acc=0.9322
# Epoch 398/500 | train_loss=0.2018 acc=1.0000 | val_loss=0.3470 acc=0.9426
# Epoch 399/500 | train_loss=0.2031 acc=1.0000 | val_loss=0.3577 acc=0.9374
# Epoch 400/500 | train_loss=0.2019 acc=1.0000 | val_loss=0.
500 | train_loss=0.2016 acc=1.0000 | val_loss=0.3616 acc=0.9339
# Epoch 475/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3613 acc=0.9322
# Epoch 476/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3637 acc=0.9304
# Epoch 477/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3641 acc=0.9339
# Epoch 478/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3639 acc=0.9339
# Epoch 479/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3644 acc=0.9304
# Epoch 480/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3644 acc=0.9304
# Epoch 481/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3639 acc=0.9304
# Epoch 482/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.3639 acc=0.9304
# Epoch 483/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.3639 acc=0.9304
# Epoch 484/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3641 acc=0.9304
# Epoch 485/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3642 acc=0.9304
# Epoch 486/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.3642 acc=0.9304
# Epoch 487/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3639 acc=0.9304
# Epoch 488/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3634 acc=0.9322
# Epoch 489/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3632 acc=0.9339
# Epoch 490/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.3632 acc=0.9322
# Epoch 491/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3632 acc=0.9322
# Epoch 492/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3631 acc=0.9322
# Epoch 493/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.3632 acc=0.9322
# Epoch 494/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3632 acc=0.9322
# Epoch 495/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3631 acc=0.9322
# Epoch 496/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3631 acc=0.9322
# Epoch 497/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3631 acc=0.9322
# Epoch 498/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3631 acc=0.9322
# Epoch 499/500 | train_loss=0.2016 acc=1.0000 | val_loss=0.3631 acc=0.9322
# Epoch 500/500 | train_loss=0.2017 acc=1.0000 | val_loss=0.3631 acc=0.9322
# Best val loss: 0.2462. Saved to: best_VGG16_Loss_brain_tumor.pt
# /tmp/ipykernel_126/1534581143.py:128: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(best_path, map_location=device)
# Test classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.9630    0.2600    0.4094       100
# meningioma_tumor     0.6726    0.9826    0.7986       115
#         no_tumor     0.8182    0.9767    0.8905       129
#  pituitary_tumor     1.0000    0.9324    0.9650        74
#
#         accuracy                         0.7990       418
#        macro avg     0.8634    0.7879    0.7659       418
#     weighted avg     0.8450    0.7990    0.7633       418
#
#
# Confusion matrix:
# [[ 26  48  26   0]
#  [  0 113   2   0]
#  [  1   2 126   0]
#  [  0   5   0  69]]

# %%
from sklearn.metrics import classification_report, confusion_matrix

val_loader = DataLoader(valset, batch_size=BATCH*2, shuffle=False,num_workers=WORKERS, pin_memory=True, drop_last=False)
best_path = "best_VGG16_Loss_brain_tumor.pt"

device = get_device()
print("Device:", device)

if val_loader is not None:
    ckpt = torch.load(best_path, map_location=device)
    model.load_state_dict(ckpt["model"])
    model.to(device)
    model.eval()
    all_preds, all_tgts = [], []
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = to_device((xb, yb), device)
            logits = model(xb)
            all_preds.append(logits.argmax(1).cpu())
            all_tgts.append(yb.cpu())


    y_pred = torch.cat(all_preds).numpy()
    y_true = torch.cat(all_tgts).numpy()
    print("\nTest classification report:")
    print(classification_report(y_true, y_pred, target_names= class_names, digits=4))
    print("\nConfusion matrix:")
    print(confusion_matrix(y_true, y_pred))
# Out:
# Device: cuda
# /tmp/ipykernel_12715/1826264693.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(best_path, map_location=device)
# Test classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.9871    0.9935    0.9903       154
# meningioma_tumor     0.9819    0.9702    0.9760       168
#         no_tumor     0.9865    0.9865    0.9865        74
#  pituitary_tumor     0.9892    0.9946    0.9919       184
#
#         accuracy                         0.9862       580
#        macro avg     0.9862    0.9862    0.9862       580
#     weighted avg     0.9862    0.9862    0.9862       580
#
#
# Confusion matrix:
# [[153   1   0   0]
#  [  2 163   1   2]
#  [  0   1  73   0]
#  [  0   1   0 183]]
