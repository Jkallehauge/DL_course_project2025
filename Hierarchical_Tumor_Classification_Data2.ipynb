# %%
#Setting up paths for data
data_root_clean = "/home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2_clean" 
data_root = "/home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2" 

#tr_base  = data_root+"/Training"
#te_base  = data_root+"/Testing"

tr_base  = data_root_clean+"/Training"
te_base  = data_root_clean+"/Testing"

# %%
#Setting up Transforms 
from pathlib import Path
from torch.utils.data import DataLoader, Subset, WeightedRandomSampler # remember subset when you divide into training and validation
from torchvision import datasets, transforms, utils, models # add models when you import pretrained models for transfer learning
import os
import torch
import numpy as np

IMG_SIZE = 512


train_tf = transforms.Compose([
    transforms.Lambda(lambda im: im.convert('L')),                 # use 'RGB' if truly 3-ch
    transforms.Grayscale(num_output_channels=1), 
    transforms.Resize((IMG_SIZE, IMG_SIZE), antialias=True),
    transforms.RandomAffine(degrees=10, translate=(0.02,0.02), scale=(0.95,1.05)),
    transforms.RandomApply([transforms.GaussianBlur(3, (0.1, 1.0))], p=0.2),
    transforms.ColorJitter(brightness=0.10, contrast=0.10),
    transforms.ToTensor(),
    #transforms.Lambda(zscore),
])

eval_tf = transforms.Compose([
    transforms.Lambda(lambda im: im.convert('L')),
    transforms.Grayscale(num_output_channels=1), 
    transforms.Resize((IMG_SIZE, IMG_SIZE), antialias=True),
    transforms.ToTensor(),
    #transforms.Lambda(zscore),
])

# %%
from torchvision import datasets
from torch.utils.data import Subset
import numpy as np

trainset = datasets.ImageFolder(tr_base, transform=train_tf)
valset   = datasets.ImageFolder(tr_base, transform=eval_tf)
testset  = datasets.ImageFolder(te_base, transform=eval_tf)

print(trainset.classes)    # should be ['glioma','meningioma','no_tumor','pituitary']
class_names = trainset.classes

# train/val split
val_fraction = 0.2
idxs = list(range(len(valset)))
rng = np.random.default_rng(42)
rng.shuffle(idxs)

n_val   = int(len(idxs) * val_fraction)
val_idx = idxs[:n_val]
train_idx = idxs[n_val:]

trainset = Subset(trainset, train_idx)
valset   = Subset(valset,   val_idx)
# testset stays as is
# Out:
# ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

# %%
def get_targets_from_dataset(ds) -> np.ndarray:
    """Return class indices for ImageFolder or Subset(ImageFolder)."""
    if isinstance(ds, Subset):
        base, idxs = ds.dataset, ds.indices
        if hasattr(base, "targets"):
            return np.asarray(base.targets, dtype=int)[idxs]
        return np.asarray([base.samples[i][1] for i in idxs], dtype=int)

    # ImageFolder
    if hasattr(ds, "targets"):
        return np.asarray(ds.targets, dtype=int)

    return np.asarray([y for _, y in ds.samples], dtype=int)

# %%
targets_4c = get_targets_from_dataset(trainset)   # original 4-class labels
class_sample_count = np.bincount(targets_4c)

# inverse frequency weights
weights = 1.0 / class_sample_count
sample_weights = torch.DoubleTensor([weights[t] for t in targets_4c])

sampler = torch.utils.data.WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),  
    replacement=True
)

# %%
from torch.utils.data import Dataset

class HierarchicalTumorDataset(Dataset):
    """
    Wraps an existing dataset (ImageFolder or Subset(ImageFolder))
    and returns: image, y_bin, y_sub

    y_bin: 0 = no_tumor, 1 = tumor
    y_sub: 0 = glioma, 1 = meningioma, 2 = pituitary, -1 = no_tumor (ignored)
    """
    def __init__(self, base_dataset, class_names, subtype_ignore_index=-1):
        self.base = base_dataset
        self.subtype_ignore_index = subtype_ignore_index

        # original label indices from ImageFolder class order
        self.glioma_idx     = class_names.index("glioma_tumor")
        self.meningioma_idx = class_names.index("meningioma_tumor")
        self.no_tumor_idx   = class_names.index("no_tumor")
        self.pituitary_idx  = class_names.index("pituitary_tumor")

        # binary mapping: tumor vs no_tumor
        self.bin_map = {
            self.glioma_idx: 1,
            self.meningioma_idx: 1,
            self.pituitary_idx: 1,
            self.no_tumor_idx: 0,
        }

        # subtype mapping (no_tumor gets ignore_index)
        self.subtype_map = {
            self.glioma_idx: 0,
            self.meningioma_idx: 1,
            self.pituitary_idx: 2,
            self.no_tumor_idx: self.subtype_ignore_index,
        }

    def __len__(self):
        return len(self.base)

    def __getitem__(self, idx):
        x, y_orig = self.base[idx]       # y_orig in {0,1,2,3} from ImageFolder
        y_bin = self.bin_map[y_orig]     # 0/1
        y_sub = self.subtype_map[y_orig] # 0/1/2 or -1
        return x, y_bin, y_sub

# %%
train_hier = HierarchicalTumorDataset(trainset, class_names)
val_hier   = HierarchicalTumorDataset(valset,   class_names)
test_hier  = HierarchicalTumorDataset(testset,  class_names)

# %%
from torch.utils.data import DataLoader

BATCH =4
WORKERS = 4
EPOCHS = 500
LR = 3e-4
# trainset, valset, testset are Subset(ImageFolder, ...)
# class_names comes from ImageFolder(tr_base).classes

train_hier = HierarchicalTumorDataset(trainset, class_names)
val_hier   = HierarchicalTumorDataset(valset,   class_names)

train_loader = DataLoader(
    train_hier,
    batch_size=BATCH,
    sampler=sampler,         # if you use one
    num_workers=WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_hier,
    batch_size=BATCH*2,
    shuffle=False,
    num_workers=WORKERS,
    pin_memory=True,
    drop_last=False
)

test_loader = DataLoader(
    test_hier,
    batch_size=BATCH*2,
    shuffle=False,
    num_workers=WORKERS,
    pin_memory=True,
    drop_last=False
)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class UNetHierMTL(nn.Module):
    """
    U-Net autoencoder with hierarchical classification head.

    Outputs:
      - recon:      reconstruction (B, out_channels, H, W)
      - logit_bin:  tumor vs no_tumor (B,)  -> use BCEWithLogitsLoss
      - logits_sub: subtype logits (B, n_subtypes) -> use CrossEntropyLoss(ignore_index=-1)
      - latent:     latent feature vector (B, cls_hidden)
    """
    def __init__(
        self,
        in_channels=1,
        out_channels=1,
        n_subtypes=3,          # glioma, meningioma, pituitary
        features=(64, 128, 256, 512),
        cls_hidden=256,
        dropout=0.2,
    ):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.n_subtypes = n_subtypes

        # ---------- Encoder ----------
        self.downs = nn.ModuleList()
        self.pool = nn.MaxPool2d(2, 2)

        ch_in = in_channels
        for ch_out in features:
            self.downs.append(self._block(ch_in, ch_out))
            ch_in = ch_out

        # ---------- Bottleneck ----------
        self.bottleneck = self._block(features[-1], features[-1] * 2)
        bottleneck_ch = features[-1] * 2

        # ---------- Decoder ----------
        self.ups = nn.ModuleList()
        for ch in reversed(features):
            self.ups.append(nn.ConvTranspose2d(bottleneck_ch, ch, kernel_size=2, stride=2))
            self.ups.append(self._block(ch * 2, ch))  # skip concat doubles channels
            bottleneck_ch = ch

        self.final_conv = nn.Conv2d(features[0], out_channels, kernel_size=1)

        # ---------- Hierarchical classification head ----------
        self.gap = nn.AdaptiveAvgPool2d(1)

        # shared latent projection (backbone part of HierarchicalNet)
        self.cls_proj = nn.Sequential(
            nn.Flatten(),                     # (B, C, 1, 1) -> (B, C)
            nn.Linear(features[-1] * 2, cls_hidden),
            nn.ReLU(inplace=True),
        )

        # binary head: tumor vs no_tumor (1 logit)
        self.head_bin = nn.Sequential(
            nn.Dropout(p=dropout),
            nn.Linear(cls_hidden, 1),
        )

        # subtype head: glioma / meningioma / pituitary
        self.head_sub = nn.Sequential(
            nn.Dropout(p=dropout),
            nn.Linear(cls_hidden, n_subtypes),
        )

    @staticmethod
    def _block(in_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x, return_latent: bool = False):
        # ---------- Encoder with skips ----------
        skips = []
        for down in self.downs:
            x = down(x)
            skips.append(x)
            x = self.pool(x)

        # ---------- Bottleneck ----------
        x = self.bottleneck(x)
        bottleneck_feat = x  # (B, C_bottleneck, H', W')

        # ---------- Classification branch ----------
        pooled = self.gap(bottleneck_feat)          # (B, C_bottleneck, 1, 1)
        latent = self.cls_proj(pooled)              # (B, cls_hidden)

        logit_bin = self.head_bin(latent).squeeze(-1)   # (B,)
        logits_sub = self.head_sub(latent)              # (B, n_subtypes)

        # ---------- Decoder ----------
        skips = skips[::-1]
        for i in range(0, len(self.ups), 2):
            x = self.ups[i](x)  # up-conv
            skip = skips[i // 2]
            if x.shape[-2:] != skip.shape[-2:]:
                x = F.interpolate(x, size=skip.shape[-2:], mode="bilinear", align_corners=False)
            x = torch.cat([skip, x], dim=1)
            x = self.ups[i + 1](x)

        recon = self.final_conv(x)

        out = {
            "recon": recon,
            "logit_bin": logit_bin,
            "logits_sub": logits_sub,
        }
        if return_latent:
            out["latent"] = latent
        return out


# quick sanity check
if __name__ == "__main__":
    model = UNetHierMTL(in_channels=1, out_channels=1, n_subtypes=3)
    inp = torch.randn(1, 1, 512, 512)
    out = model(inp, return_latent=True)
    print(out["recon"].shape, out["logit_bin"].shape, out["logits_sub"].shape, out["latent"].shape)
# Out:
# torch.Size([1, 1, 512, 512]) torch.Size([1]) torch.Size([1, 3]) torch.Size([1, 256])

# %%
import torch

# Use the same model + wrapper as above
base_model = UNetHierMTL(in_channels=1, out_channels=1, n_subtypes=3)
model = UNetHierMTLWrapper(base_model).eval()

dummy = torch.randn(1, 1, 512, 512)  # example input

torch.onnx.export(
    model,
    dummy,
    "UNetHierMTL.onnx",
    input_names=["input"],
    output_names=["recon", "logit_bin", "logits_sub", "latent"],
    opset_version=13,
    do_constant_folding=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 5
#       3 # Use the same model + wrapper as above
#       4 base_model = UNetHierMTL(in_channels=1, out_channels=1, n_subtypes=3)
# ----> 5 model = UNetHierMTLWrapper(base_model).eval()
#       7 dummy = torch.randn(1, 1, 512, 512)  # example input
#       9 torch.onnx.export(
#      10     model,
#      11     dummy,
#    (...)
#      16     do_constant_folding=True
#      17 )
#
# NameError: name 'UNetHierMTLWrapper' is not defined

# %%
import torch
import contextlib
import torch.nn.functional as F

def epoch_run(
    model,
    loader,
    device,
    train: bool,
    use_amp: bool,          # keep flag, but we only use it for autocast
    optimizer=None,
    ema_recon: float = 1.0,
    ema_cls: float = 1.0,
    beta: float = 0.99,
    alpha_sub: float = 1.0,
    bin_thresh: float = 0.5
):
    """
    Hierarchical multi-task epoch:

      - reconstruction
      - binary tumor vs no_tumor
      - subtype classification for tumor cases

    Dataloader must yield: xb, y_bin, y_sub

    Returns
    -------
    avg_loss, acc_4class, bin_acc, sub_acc_tumor, avg_recon_loss, avg_cls_loss
    """

    recon_criterion = torch.nn.MSELoss()
    bin_criterion   = torch.nn.BCEWithLogitsLoss()
    sub_criterion   = torch.nn.CrossEntropyLoss(ignore_index=-1)

    assert (train and optimizer is not None) or (not train)

    model.train() if train else model.eval()

    total = 0
    running_loss = 0.0
    running_recon = 0.0
    running_cls = 0.0

    correct_4 = 0
    correct_bin = 0
    total_bin = 0

    correct_sub_tumor = 0
    total_sub_tumor = 0

    cm = contextlib.nullcontext() if train else torch.no_grad()
    amp_enabled = use_amp and (device.type == 'cuda')

    with cm:
        for xb, y_bin, y_sub in loader:
            xb    = xb.to(device, non_blocking=True)
            y_bin = y_bin.to(device, non_blocking=True).float()
            y_sub = y_sub.to(device, non_blocking=True)

            with torch.amp.autocast('cuda', enabled=amp_enabled):
                out = model(xb)
                recon      = out["recon"]
                logit_bin  = out["logit_bin"]    # (B,)
                logits_sub = out["logits_sub"]   # (B, 3)

                # --- reconstruction + binary loss ---
                recon_loss = recon_criterion(recon, xb)
                bin_loss   = bin_criterion(logit_bin, y_bin)

                # --- subtype loss: ONLY if any valid labels (y_sub != -1) ---
                valid_sub_mask = (y_sub != -1)
                if valid_sub_mask.any():
                    sub_loss = sub_criterion(
                        logits_sub[valid_sub_mask],
                        y_sub[valid_sub_mask]
                    )
                else:
                    sub_loss = torch.zeros((), device=device)

                cls_loss = bin_loss + alpha_sub * sub_loss

                # --- EMA updates (detach) ---
                ema_recon = beta * ema_recon + (1.0 - beta) * float(recon_loss.detach())
                ema_cls   = beta * ema_cls   + (1.0 - beta) * float(cls_loss.detach())

                # --- normalized losses ---
                recon_norm = recon_loss / max(ema_recon, 1e-12)
                cls_norm   = cls_loss   / max(ema_cls,   1e-12)

                loss = recon_norm + cls_norm

            if train:
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                optimizer.step()

            # ---- Accumulate losses ----
            bs = xb.size(0)
            running_loss  += loss.detach().float().item() * bs
            running_recon += recon_norm.detach().float().item() * bs
            running_cls   += cls_norm.detach().float().item() * bs
            total += bs

            # ---- Predictions ----
            prob_bin = torch.sigmoid(logit_bin)          # (B,)
            pred_bin = (prob_bin >= bin_thresh).long()   # 0=no_tumor, 1=tumor
            pred_sub = logits_sub.argmax(dim=1)          # (B,)

            # 4-class labels: 0,1,2=subtypes; 3=no_tumor
            pred_4 = torch.where(
                pred_bin == 0,
                torch.full_like(pred_sub, 3),
                pred_sub
            )
            true_4 = torch.where(
                y_bin.long() == 0,
                torch.full_like(y_sub, 3),
                y_sub
            )

            correct_4 += (pred_4 == true_4).sum().item()

            # binary accuracy
            correct_bin += (pred_bin == y_bin.long()).sum().item()
            total_bin   += bs

            # subtype accuracy on tumor cases only
            tumor_mask = (y_bin.long() == 1) & (y_sub != -1)
            if tumor_mask.any():
                correct_sub_tumor += (pred_sub[tumor_mask] == y_sub[tumor_mask]).sum().item()
                total_sub_tumor   += tumor_mask.sum().item()

    avg_loss = running_loss / total
    avg_recon_loss = running_recon / total
    avg_cls_loss = running_cls / total

    acc_4class = correct_4 / total
    bin_acc = correct_bin / total_bin if total_bin > 0 else float('nan')
    sub_acc_tumor = (
        correct_sub_tumor / total_sub_tumor if total_sub_tumor > 0 else float('nan')
    )

    return avg_loss, acc_4class, bin_acc, sub_acc_tumor, avg_recon_loss, avg_cls_loss

# %%
def set_seed(seed=42):
    random.seed(seed); np.random.seed(seed); torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

def get_device():
    return torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def to_device(batch, device):
    x, y = batch
    return x.to(device, non_blocking=True), y.to(device, non_blocking=True)

# %%
xb, y_bin, y_sub = next(iter(train_loader))
print(xb.shape, y_bin.shape, y_sub.shape)
print("unique y_bin:", torch.unique(y_bin))
print("unique y_sub:", torch.unique(y_sub))
# Out:
# torch.Size([4, 1, 512, 512]) torch.Size([4]) torch.Size([4])
# unique y_bin: tensor([0, 1])
# unique y_sub: tensor([-1,  0,  2])

# %%
# ----------------------------
# 3) Training utilities
# ----------------------------
class EarlyStopper:
    def __init__(self, patience=8, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best = None
        self.count = 0

    def step(self, metric):
        if self.best is None or metric > self.best + self.min_delta:
            self.best = metric
            self.count = 0
            return False  # do not stop

# %%
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import Counter
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from torch import amp
import json

seed=2025
set_seed(seed)
device = get_device()
print("Device:", device)

DATA_ROOT = data_root 
BATCH = 32
EPOCHS = 100
LR = 3e-4
FREEZE_BACKBONE = False  # set True to train only the last layer first

#counts = torch.tensor([670, 653, 328, 652], dtype=torch.float32)
#beta = 0.999  # can be tuned in [0.99, 0.9999]

#effective_num = 1.0 - beta ** counts
#weights = (1.0 - beta) / effective_num
#weights = weights / weights.sum() * len(counts)
#print(weights)

#trainset, valset, testset, class_names = build_datasets(DATA_ROOT, img_size=224, val_fraction=0.15)
print("Classes:", class_names)

#scaler = amp.GradScaler('cuda', enabled=(device.type=='cuda'))
history = {
    "train_loss":      [],
    "train_acc4":      [],
    "train_bin_acc":   [],
    "train_sub_acc":   [],
    "train_recon":     [],
    "train_cls":       [],
    "val_loss":        [],
    "val_acc4":        [],
    "val_bin_acc":     [],
    "val_sub_acc":     [],
    "val_recon":       [],
    "val_cls":         [],
}

train_loader = DataLoader(
    train_hier,
    batch_size=BATCH,
    sampler=sampler,
    num_workers=WORKERS,
    pin_memory=True
)

val_loader = DataLoader(
    val_hier,
    batch_size=BATCH*2,
    shuffle=False,
    num_workers=WORKERS,
    pin_memory=True,
    drop_last=False
)

test_loader = DataLoader(
    test_hier,
    batch_size=BATCH*2,
    shuffle=False,
    num_workers=WORKERS,
    pin_memory=True,
    drop_last=False
)

print("Train uses sampler:", train_loader.sampler.__class__.__name__)
print("Val uses sampler:  ", val_loader.sampler.__class__.__name__)
print("Test uses sampler: ", test_loader.sampler.__class__.__name__)

model = UNetHierMTL(in_channels=1, out_channels=1, n_subtypes=3)
model.to(device)

scaler = amp.GradScaler('cuda', enabled=(device.type=='cuda'))
optimizer = torch.optim.AdamW(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)


best_loss, best_acc, best_path, best_path_acc = 1000, 0.0, "best_AE_Loss_brain_tumor_MTL_Lat_Hier2_clean.pt", "best_AE_Acc_brain_tumor_MTL_Lat_Hier2_clean.pt"
stopper = EarlyStopper(patience=7, min_delta=1e-4)

for epoch in range(1, EPOCHS+1):
    train_loss, train_acc4, train_bin_acc, train_sub_acc, train_recon, train_cls = epoch_run(
        model, train_loader, device,
        train=True, use_amp=False,          # start with False, can set True later
        optimizer=optimizer,
        ema_recon=0.0004, ema_cls=1.0, beta=0.99
    )

    val_loss, val_acc4, val_bin_acc, val_sub_acc, val_recon, val_cls = epoch_run(
        model, val_loader, device,
        train=False, use_amp=False,
        ema_recon=0.0004, ema_cls=1.0, beta=0.99
    )

    print(
        f"Train | total {train_loss:.4f} | acc4 {train_acc4:.3f} | "
        f"bin {train_bin_acc:.3f} | sub_tumor {train_sub_acc:.3f} | "
        f"recon {train_recon:.4f} | cls {train_cls:.4f}"
    )
    print(
        f"Val   | total {val_loss:.4f} | acc4 {val_acc4:.3f} | "
        f"bin {val_bin_acc:.3f} | sub_tumor {val_sub_acc:.3f} | "
        f"recon {val_recon:.4f} | cls {val_cls:.4f}"
    )

    scheduler.step()

    # log
    history["train_loss"].append(train_loss)
    history["train_acc4"].append(train_acc4)
    history["train_bin_acc"].append(train_bin_acc)
    history["train_sub_acc"].append(train_sub_acc)
    history["train_recon"].append(train_recon)
    history["train_cls"].append(train_cls)

    history["val_loss"].append(val_loss)
    history["val_acc4"].append(val_acc4)
    history["val_bin_acc"].append(val_bin_acc)
    history["val_sub_acc"].append(val_sub_acc)
    history["val_recon"].append(val_recon)
    history["val_cls"].append(val_cls)

    # ---------------- best model tracking ----------------
    color = ""
    end_color = "\033[0m"
    style_bold = "\033[1m"
    suffix = ""

    # For consistency, use 4-class accuracy for "acc"
    val_acc = val_acc4

    if val_loss < best_loss and val_acc > best_acc:
        best_loss = val_loss
        best_acc = val_acc
        color = "\033[96m"  # cyan
        suffix = " 🟢⭐ (new best loss & acc)"
        torch.save({"model": model.state_dict(),
                    "classes": class_names}, best_path)

    elif val_loss < best_loss:
        best_loss = val_loss
        color = "\033[92m"  # green
        suffix = " ✅ (new best loss)"
        torch.save({"model": model.state_dict(),
                    "classes": class_names}, best_path)

    elif val_acc > best_acc:
        best_acc = val_acc
        color = "\033[94m"  # blue
        suffix = " 💙 (new best acc)"
        torch.save({"model": model.state_dict(),
                    "classes": class_names}, best_path_acc)

    print(f"{color}{style_bold}"
          f"Epoch {epoch:02d}/{EPOCHS} | "
          f"train_loss={train_loss:.4f} acc4={train_acc4:.4f} | "
          f"val_loss={val_loss:.4f} acc4={val_acc4:.4f}"
          f"{suffix}{end_color}")



    if stopper.step(val_acc):
        print("Early stopping triggered.")
        break

print(f"Best val loss: {best_loss:.4f}. Saved to: {best_path}")

with open("history_AE_MTL_latent_Hier2_clean.json", "w") as f:
    json.dump(history, f)
# Out:
# Device: cuda
# Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# Train uses sampler: WeightedRandomSampler
# Val uses sampler:   SequentialSampler
# Test uses sampler:  SequentialSampler
# Train | total 2.8151 | acc4 0.668 | bin 0.911 | sub_tumor 0.667 | recon 1.8363 | cls 0.9788
# Val   | total 2.5099 | acc4 0.771 | bin 0.953 | sub_tumor 0.768 | recon 1.7616 | cls 0.7483
# Epoch 01/100 | train_loss=2.8151 acc4=0.6681 | val_loss=2.5099 acc4=0.7711 🟢⭐ (new best loss & acc)
# Train | total 2.2930 | acc4 0.734 | bin 0.936 | sub_tumor 0.729 | recon 1.4243 | cls 0.8687
# Val   | total 1.7371 | acc4 0.561 | bin 0.663 | sub_tumor 0.643 | recon 0.3833 | cls 1.3538
# Epoch 02/100 | train_loss=2.2930 acc4=0.7344 | val_loss=1.7371 acc4=0.5610 ✅ (new best loss)
# Train | total 2.0964 | acc4 0.760 | bin 0.943 | sub_tumor 0.748 | recon 1.2680 | cls 0.8285
# Val   | total 1.0435 | acc4 0.750 | bin 0.914 | sub_tumor 0.781 | recon 0.3014 | cls 0.7421
# Epoch 03/100 | train_loss=2.0964 acc4=0.7599 | val_loss=1.0435 acc4=0.7502 ✅ (new best loss)
# Train | total 1.9913 | acc4 0.799 | bin 0.937 | sub_tumor 0.808 | recon 1.2268 | cls 0.7645
# Val   | total 2.0328 | acc4 0.575 | bin 0.914 | sub_tumor 0.567 | recon 0.8551 | cls 1.1777
# Epoch 04/100 | train_loss=1.9913 acc4=0.7985 | val_loss=2.0328 acc4=0.5748
# Train | total 1.9322 | acc4 0.816 | bin 0.947 | sub_tumor 0.816 | recon 1.2047 | cls 0.7275
# Val   | total 0.8899 | acc4 0.789 | bin 0.931 | sub_tumor 0.817 | recon 0.2159 | cls 0.6740
# Epoch 05/100 | train_loss=1.9322 acc4=0.8158 | val_loss=0.8899 acc4=0.7889 🟢⭐ (new best loss & acc)
# Train | total 1.8127 | acc4 0.838 | bin 0.952 | sub_tumor 0.842 | recon 1.1336 | cls 0.6791
# Val   | total 2.0391 | acc4 0.631 | bin 0.792 | sub_tumor 0.657 | recon 0.8061 | cls 1.2329
# Epoch 06/100 | train_loss=1.8127 acc4=0.8376 | val_loss=2.0391 acc4=0.6313
# Train | total 1.7613 | acc4 0.839 | bin 0.954 | sub_tumor 0.841 | recon 1.0992 | cls 0.6621
# Val   | total 1.1269 | acc4 0.846 | bin 0.961 | sub_tumor 0.850 | recon 0.6012 | cls 0.5257
# Epoch 07/100 | train_loss=1.7613 acc4=0.8386 | val_loss=1.1269 acc4=0.8464 💙 (new best acc)
# Train | total 1.5429 | acc4 0.858 | bin 0.962 | sub_tumor 0.860 | recon 0.9393 | cls 0.6036
# Val   | total 1.2322 | acc4 0.824 | bin 0.943 | sub_tumor 0.846 | recon 0.6580 | cls 0.5743
# Epoch 08/100 | train_loss=1.5429 acc4=0.8584 | val_loss=1.2322 acc4=0.8236
# Train | total 1.5793 | acc4 0.853 | bin 0.960 | sub_tumor 0.855 | recon 0.9442 | cls 0.6351
# Val   | total 0.5549 | acc4 0.869 | bin 0.966 | sub_tumor 0.875 | recon 0.1278 | cls 0.4271
# Epoch 09/100 | train_loss=1.5793 acc4=0.8530 | val_loss=0.5549 acc4=0.8692 🟢⭐ (new best loss & acc)
# Train | total 1.7259 | acc4 0.863 | bin 0.957 | sub_tumor 0.871 | recon 1.1016 | cls 0.6244
# Val   | total 1.4320 | acc4 0.599 | bin 0.958 | sub_tumor 0.546 | recon 0.2818 | cls 1.1502
# Epoch 10/100 | train_loss=1.7259 acc4=0.8631 | val_loss=1.4320 acc4=0.5986
# Train | total 1.6410 | acc4 0.865 | bin 0.960 | sub_tumor 0.867 | recon 1.0169 | cls 0.6241
# Val   | total 1.0885 | acc4 0.827 | bin 0.944 | sub_tumor 0.851 | recon 0.5224 | cls 0.5661
# Epoch 11/100 | train_loss=1.6410 acc4=0.8646 | val_loss=1.0885 acc4=0.8266
# Train | total 1.5530 | acc4 0.867 | bin 0.964 | sub_tumor 0.868 | recon 0.9616 | cls 0.5914
# Val   | total 0.9859 | acc4 0.835 | bin 0.954 | sub_tumor 0.846 | recon 0.4184 | cls 0.5676
# Epoch 12/100 | train_loss=1.5530 acc4=0.8671 | val_loss=0.9859 acc4=0.8355
# Train | total 1.5438 | acc4 0.867 | bin 0.961 | sub_tumor 0.874 | recon 0.9561 | cls 0.5877
# Val   | total 0.9500 | acc4 0.762 | bin 0.932 | sub_tumor 0.765 | recon 0.2677 | cls 0.6822
# Epoch 13/100 | train_loss=1.5438 acc4=0.8671 | val_loss=0.9500 acc4=0.7621
# Train | total 1.3703 | acc4 0.884 | bin 0.964 | sub_tumor 0.890 | recon 0.8301 | cls 0.5401
# Val   | total 0.9294 | acc4 0.805 | bin 0.968 | sub_tumor 0.793 | recon 0.2933 | cls 0.6362
# Epoch 14/100 | train_loss=1.3703 acc4=0.8842 | val_loss=0.9294 acc4=0.8048
# Train | total 1.5088 | acc4 0.881 | bin 0.965 | sub_tumor 0.885 | recon 0.9563 | cls 0.5525
# Val   | total 0.7832 | acc4 0.809 | bin 0.975 | sub_tumor 0.788 | recon 0.1834 | cls 0.5998
# Epoch 15/100 | train_loss=1.5088 acc4=0.8807 | val_loss=0.7832 acc4=0.8087
# Train | total 1.5156 | acc4 0.891 | bin 0.971 | sub_tumor 0.893 | recon 0.9863 | cls 0.5293
# Val   | total 3.6645 | acc4 0.687 | bin 0.935 | sub_tumor 0.660 | recon 1.5214 | cls 2.1431
# Epoch 16/100 | train_loss=1.5156 acc4=0.8913 | val_loss=3.6645 acc4=0.6868
# Train | total 1.4004 | acc4 0.888 | bin 0.966 | sub_tumor 0.894 | recon 0.8835 | cls 0.5169
# Val   | total 0.7370 | acc4 0.875 | bin 0.980 | sub_tumor 0.866 | recon 0.2746 | cls 0.4624
# Epoch 17/100 | train_loss=1.4004 acc4=0.8881 | val_loss=0.7370 acc4=0.8751 💙 (new best acc)
# Train | total 1.3490 | acc4 0.888 | bin 0.970 | sub_tumor 0.891 | recon 0.8174 | cls 0.5317
# Val   | total 0.8443 | acc4 0.881 | bin 0.972 | sub_tumor 0.885 | recon 0.4603 | cls 0.3841
# Epoch 18/100 | train_loss=1.3490 acc4=0.8884 | val_loss=0.8443 acc4=0.8811 💙 (new best acc)
# Train | total 1.3582 | acc4 0.900 | bin 0.968 | sub_tumor 0.908 | recon 0.8596 | cls 0.4986
# Val   | total 0.6967 | acc4 0.868 | bin 0.975 | sub_tumor 0.864 | recon 0.2896 | cls 0.4071
# Epoch 19/100 | train_loss=1.3582 acc4=0.9005 | val_loss=0.6967 acc4=0.8682
# Train | total 1.1920 | acc4 0.907 | bin 0.971 | sub_tumor 0.912 | recon 0.6993 | cls 0.4926
# Val   | total 0.8167 | acc4 0.808 | bin 0.974 | sub_tumor 0.790 | recon 0.2538 | cls 0.5628
# Epoch 20/100 | train_loss=1.1920 acc4=0.9067 | val_loss=0.8167 acc4=0.8077
# Train | total 1.1218 | acc4 0.914 | bin 0.974 | sub_tumor 0.919 | recon 0.6711 | cls 0.4507
# Val   | total 0.7398 | acc4 0.806 | bin 0.980 | sub_tumor 0.778 | recon 0.1118 | cls 0.6280
# Epoch 21/100 | train_loss=1.1218 acc4=0.9144 | val_loss=0.7398 acc4=0.8057
# Train | total 1.1560 | acc4 0.905 | bin 0.974 | sub_tumor 0.908 | recon 0.6903 | cls 0.4656
# Val   | total 0.7596 | acc4 0.900 | bin 0.976 | sub_tumor 0.902 | recon 0.4377 | cls 0.3220
# Epoch 22/100 | train_loss=1.1560 acc4=0.9052 | val_loss=0.7596 acc4=0.8999 💙 (new best acc)
# Train | total 1.2085 | acc4 0.902 | bin 0.971 | sub_tumor 0.906 | recon 0.7434 | cls 0.4651
# Val   | total 0.5150 | acc4 0.908 | bin 0.968 | sub_tumor 0.922 | recon 0.1844 | cls 0.3305
# Epoch 23/100 | train_loss=1.2085 acc4=0.9022 | val_loss=0.5150 acc4=0.9078 🟢⭐ (new best loss & acc)
# Train | total 1.0371 | acc4 0.906 | bin 0.975 | sub_tumor 0.908 | recon 0.5847 | cls 0.4524
# Val   | total 0.6499 | acc4 0.856 | bin 0.979 | sub_tumor 0.845 | recon 0.0828 | cls 0.5671
# Epoch 24/100 | train_loss=1.0371 acc4=0.9059 | val_loss=0.6499 acc4=0.8563
# Train | total 1.0604 | acc4 0.915 | bin 0.974 | sub_tumor 0.919 | recon 0.6365 | cls 0.4240
# Val   | total 0.7609 | acc4 0.829 | bin 0.974 | sub_tumor 0.812 | recon 0.1609 | cls 0.6000
# Epoch 25/100 | train_loss=1.0604 acc4=0.9149 | val_loss=0.7609 acc4=0.8285
# Train | total 1.0368 | acc4 0.913 | bin 0.972 | sub_tumor 0.920 | recon 0.6194 | cls 0.4174
# Val   | total 0.9393 | acc4 0.901 | bin 0.978 | sub_tumor 0.901 | recon 0.6040 | cls 0.3354
# Epoch 26/100 | train_loss=1.0368 acc4=0.9129 | val_loss=0.9393 acc4=0.9009
# Train | total 1.0078 | acc4 0.923 | bin 0.978 | sub_tumor 0.927 | recon 0.5964 | cls 0.4114
# Val   | total 0.9198 | acc4 0.840 | bin 0.976 | sub_tumor 0.827 | recon 0.3597 | cls 0.5602
# Epoch 27/100 | train_loss=1.0078 acc4=0.9230 | val_loss=0.9198 acc4=0.8404
# Train | total 1.0203 | acc4 0.918 | bin 0.976 | sub_tumor 0.920 | recon 0.6258 | cls 0.3946
# Val   | total 0.6707 | acc4 0.856 | bin 0.977 | sub_tumor 0.847 | recon 0.1399 | cls 0.5308
# Epoch 28/100 | train_loss=1.0203 acc4=0.9183 | val_loss=0.6707 acc4=0.8563
# Train | total 0.9733 | acc4 0.927 | bin 0.977 | sub_tumor 0.932 | recon 0.5673 | cls 0.4060
# Val   | total 0.9368 | acc4 0.872 | bin 0.978 | sub_tumor 0.866 | recon 0.3551 | cls 0.5817
# Epoch 29/100 | train_loss=0.9733 acc4=0.9272 | val_loss=0.9368 acc4=0.8722
# Train | total 0.9696 | acc4 0.927 | bin 0.978 | sub_tumor 0.932 | recon 0.6001 | cls 0.3696
# Val   | total 0.8508 | acc4 0.839 | bin 0.973 | sub_tumor 0.830 | recon 0.2384 | cls 0.6124
# Epoch 30/100 | train_loss=0.9696 acc4=0.9270 | val_loss=0.8508 acc4=0.8394
# Train | total 0.9863 | acc4 0.916 | bin 0.974 | sub_tumor 0.922 | recon 0.5578 | cls 0.4285
# Val   | total 0.5225 | acc4 0.897 | bin 0.976 | sub_tumor 0.899 | recon 0.1749 | cls 0.3477
# Epoch 31/100 | train_loss=0.9863 acc4=0.9158 | val_loss=0.5225 acc4=0.8969
# Train | total 0.8843 | acc4 0.937 | bin 0.978 | sub_tumor 0.942 | recon 0.5395 | cls 0.3448
# Val   | total 0.4106 | acc4 0.904 | bin 0.979 | sub_tumor 0.902 | recon 0.0558 | cls 0.3548
# Epoch 32/100 | train_loss=0.8843 acc4=0.9369 | val_loss=0.4106 acc4=0.9039 ✅ (new best loss)
# Train | total 0.8831 | acc4 0.933 | bin 0.982 | sub_tumor 0.934 | recon 0.5177 | cls 0.3654
# Val   | total 0.6735 | acc4 0.896 | bin 0.965 | sub_tumor 0.909 | recon 0.2877 | cls 0.3859
# Epoch 33/100 | train_loss=0.8831 acc4=0.9329 | val_loss=0.6735 acc4=0.8959
# Train | total 0.8266 | acc4 0.932 | bin 0.977 | sub_tumor 0.939 | recon 0.4753 | cls 0.3514
# Val   | total 0.4392 | acc4 0.941 | bin 0.980 | sub_tumor 0.950 | recon 0.2250 | cls 0.2143
# Epoch 34/100 | train_loss=0.8266 acc4=0.9317 | val_loss=0.4392 acc4=0.9405 💙 (new best acc)
# Train | total 0.7953 | acc4 0.943 | bin 0.981 | sub_tumor 0.946 | recon 0.4835 | cls 0.3118
# Val   | total 0.9225 | acc4 0.829 | bin 0.974 | sub_tumor 0.816 | recon 0.0708 | cls 0.8517
# Epoch 35/100 | train_loss=0.7953 acc4=0.9426 | val_loss=0.9225 acc4=0.8285
# Train | total 0.9355 | acc4 0.932 | bin 0.979 | sub_tumor 0.937 | recon 0.5828 | cls 0.3528
# Val   | total 0.4458 | acc4 0.924 | bin 0.979 | sub_tumor 0.930 | recon 0.1883 | cls 0.2575
# Epoch 36/100 | train_loss=0.9355 acc4=0.9324 | val_loss=0.4458 acc4=0.9237
# Train | total 0.7602 | acc4 0.939 | bin 0.982 | sub_tumor 0.943 | recon 0.4467 | cls 0.3135
# Val   | total 1.6773 | acc4 0.727 | bin 0.985 | sub_tumor 0.675 | recon 0.4227 | cls 1.2546
# Epoch 37/100 | train_loss=0.7602 acc4=0.9394 | val_loss=1.6773 acc4=0.7275
# Train | total 0.7962 | acc4 0.937 | bin 0.979 | sub_tumor 0.943 | recon 0.4902 | cls 0.3060
# Val   | total 0.3011 | acc4 0.924 | bin 0.978 | sub_tumor 0.929 | recon 0.0494 | cls 0.2517
# Epoch 38/100 | train_loss=0.7962 acc4=0.9374 | val_loss=0.3011 acc4=0.9237 ✅ (new best loss)
# Train | total 0.7916 | acc4 0.942 | bin 0.979 | sub_tumor 0.949 | recon 0.4689 | cls 0.3227
# Val   | total 0.8326 | acc4 0.811 | bin 0.978 | sub_tumor 0.787 | recon 0.1417 | cls 0.6909
# Epoch 39/100 | train_loss=0.7916 acc4=0.9416 | val_loss=0.8326 acc4=0.8107
# Train | total 0.8159 | acc4 0.949 | bin 0.982 | sub_tumor 0.955 | recon 0.5208 | cls 0.2950
# Val   | total 0.4730 | acc4 0.922 | bin 0.987 | sub_tumor 0.916 | recon 0.1523 | cls 0.3208
# Epoch 40/100 | train_loss=0.8159 acc4=0.9490 | val_loss=0.4730 acc4=0.9217
# Train | total 0.6743 | acc4 0.956 | bin 0.987 | sub_tumor 0.959 | recon 0.4194 | cls 0.2549
# Val   | total 0.3639 | acc4 0.906 | bin 0.986 | sub_tumor 0.897 | recon 0.0518 | cls 0.3121
# Epoch 41/100 | train_loss=0.6743 acc4=0.9564 | val_loss=0.3639 acc4=0.9058
# Train | total 0.8394 | acc4 0.946 | bin 0.981 | sub_tumor 0.952 | recon 0.5446 | cls 0.2948
# Val   | total 1.5578 | acc4 0.717 | bin 0.982 | sub_tumor 0.665 | recon 0.3275 | cls 1.2303
# Epoch 42/100 | train_loss=0.8394 acc4=0.9463 | val_loss=1.5578 acc4=0.7166
# Train | total 0.7006 | acc4 0.948 | bin 0.980 | sub_tumor 0.958 | recon 0.4339 | cls 0.2667
# Val   | total 0.2985 | acc4 0.934 | bin 0.966 | sub_tumor 0.959 | recon 0.0668 | cls 0.2317
# Epoch 43/100 | train_loss=0.7006 acc4=0.9483 | val_loss=0.2985 acc4=0.9336 ✅ (new best loss)
# Train | total 0.6258 | acc4 0.953 | bin 0.981 | sub_tumor 0.961 | recon 0.3775 | cls 0.2484
# Val   | total 0.6488 | acc4 0.894 | bin 0.983 | sub_tumor 0.886 | recon 0.2272 | cls 0.4216
# Epoch 44/100 | train_loss=0.6258 acc4=0.9527 | val_loss=0.6488 acc4=0.8940
# Train | total 0.7606 | acc4 0.945 | bin 0.978 | sub_tumor 0.955 | recon 0.4643 | cls 0.2963
# Val   | total 0.4982 | acc4 0.908 | bin 0.989 | sub_tumor 0.896 | recon 0.1743 | cls 0.3239
# Epoch 45/100 | train_loss=0.7606 acc4=0.9453 | val_loss=0.4982 acc4=0.9078
# Train | total 0.7231 | acc4 0.962 | bin 0.985 | sub_tumor 0.968 | recon 0.5114 | cls 0.2117
# Val   | total 0.6694 | acc4 0.904 | bin 0.985 | sub_tumor 0.897 | recon 0.1512 | cls 0.5182
# Epoch 46/100 | train_loss=0.7231 acc4=0.9621 | val_loss=0.6694 acc4=0.9039
# Train | total 0.6342 | acc4 0.955 | bin 0.982 | sub_tumor 0.964 | recon 0.3834 | cls 0.2509
# Val   | total 0.4937 | acc4 0.901 | bin 0.986 | sub_tumor 0.891 | recon 0.0801 | cls 0.4136
# Epoch 47/100 | train_loss=0.6342 acc4=0.9554 | val_loss=0.4937 acc4=0.9009
# Train | total 0.6042 | acc4 0.958 | bin 0.982 | sub_tumor 0.967 | recon 0.3722 | cls 0.2320
# Val   | total 0.5087 | acc4 0.930 | bin 0.990 | sub_tumor 0.924 | recon 0.2140 | cls 0.2947
# Epoch 48/100 | train_loss=0.6042 acc4=0.9582 | val_loss=0.5087 acc4=0.9296
# Train | total 0.6063 | acc4 0.961 | bin 0.988 | sub_tumor 0.965 | recon 0.3603 | cls 0.2460
# Val   | total 0.2777 | acc4 0.926 | bin 0.983 | sub_tumor 0.927 | recon 0.0521 | cls 0.2256
# Epoch 49/100 | train_loss=0.6063 acc4=0.9614 | val_loss=0.2777 acc4=0.9257 ✅ (new best loss)
# Train | total 0.5948 | acc4 0.963 | bin 0.990 | sub_tumor 0.964 | recon 0.3679 | cls 0.2269
# Val   | total 1.4287 | acc4 0.728 | bin 0.990 | sub_tumor 0.670 | recon 0.0658 | cls 1.3629
# Epoch 50/100 | train_loss=0.5948 acc4=0.9631 | val_loss=1.4287 acc4=0.7284
# Train | total 0.6014 | acc4 0.963 | bin 0.985 | sub_tumor 0.969 | recon 0.3779 | cls 0.2235
# Val   | total 0.6280 | acc4 0.884 | bin 0.976 | sub_tumor 0.882 | recon 0.1319 | cls 0.4961
# Epoch 51/100 | train_loss=0.6014 acc4=0.9629 | val_loss=0.6280 acc4=0.8840
# Train | total 0.6060 | acc4 0.947 | bin 0.983 | sub_tumor 0.952 | recon 0.3497 | cls 0.2563
# Val   | total 2.1505 | acc4 0.629 | bin 0.977 | sub_tumor 0.561 | recon 0.0406 | cls 2.1099
# Epoch 52/100 | train_loss=0.6060 acc4=0.9473 | val_loss=2.1505 acc4=0.6293
# Train | total 0.6240 | acc4 0.951 | bin 0.980 | sub_tumor 0.961 | recon 0.3724 | cls 0.2515
# Val   | total 0.6402 | acc4 0.858 | bin 0.990 | sub_tumor 0.832 | recon 0.0816 | cls 0.5586
# Epoch 53/100 | train_loss=0.6240 acc4=0.9507 | val_loss=0.6402 acc4=0.8583
# Train | total 0.5410 | acc4 0.965 | bin 0.986 | sub_tumor 0.972 | recon 0.3399 | cls 0.2011
# Val   | total 0.1589 | acc4 0.967 | bin 0.985 | sub_tumor 0.977 | recon 0.0334 | cls 0.1255
# Epoch 54/100 | train_loss=0.5410 acc4=0.9653 | val_loss=0.1589 acc4=0.9673 🟢⭐ (new best loss & acc)
# Train | total 0.5400 | acc4 0.970 | bin 0.987 | sub_tumor 0.977 | recon 0.3706 | cls 0.1695
# Val   | total 0.2339 | acc4 0.956 | bin 0.987 | sub_tumor 0.961 | recon 0.0762 | cls 0.1578
# Epoch 55/100 | train_loss=0.5400 acc4=0.9698 | val_loss=0.2339 acc4=0.9564
# Train | total 0.6310 | acc4 0.969 | bin 0.986 | sub_tumor 0.977 | recon 0.4569 | cls 0.1741
# Val   | total 1.0705 | acc4 0.903 | bin 0.992 | sub_tumor 0.887 | recon 0.5313 | cls 0.5392
# Epoch 56/100 | train_loss=0.6310 acc4=0.9691 | val_loss=1.0705 acc4=0.9029
# Train | total 0.6325 | acc4 0.971 | bin 0.987 | sub_tumor 0.977 | recon 0.4708 | cls 0.1617
# Val   | total 0.3107 | acc4 0.953 | bin 0.986 | sub_tumor 0.959 | recon 0.1172 | cls 0.1935
# Epoch 57/100 | train_loss=0.6325 acc4=0.9705 | val_loss=0.3107 acc4=0.9534
# Train | total 0.4791 | acc4 0.974 | bin 0.988 | sub_tumor 0.982 | recon 0.3235 | cls 0.1556
# Val   | total 0.4188 | acc4 0.908 | bin 0.992 | sub_tumor 0.894 | recon 0.0625 | cls 0.3563
# Epoch 58/100 | train_loss=0.4791 acc4=0.9740 | val_loss=0.4188 acc4=0.9078
# Train | total 0.4902 | acc4 0.974 | bin 0.987 | sub_tumor 0.981 | recon 0.3270 | cls 0.1632
# Val   | total 0.4249 | acc4 0.968 | bin 0.989 | sub_tumor 0.972 | recon 0.3105 | cls 0.1144
# Epoch 59/100 | train_loss=0.4902 acc4=0.9738 | val_loss=0.4249 acc4=0.9683 💙 (new best acc)
# Train | total 0.5577 | acc4 0.974 | bin 0.987 | sub_tumor 0.982 | recon 0.4112 | cls 0.1465
# Val   | total 0.3536 | acc4 0.953 | bin 0.990 | sub_tumor 0.954 | recon 0.1875 | cls 0.1661
# Epoch 60/100 | train_loss=0.5577 acc4=0.9738 | val_loss=0.3536 acc4=0.9534
# Train | total 0.4977 | acc4 0.976 | bin 0.989 | sub_tumor 0.982 | recon 0.3459 | cls 0.1519
# Val   | total 0.3245 | acc4 0.961 | bin 0.992 | sub_tumor 0.960 | recon 0.1669 | cls 0.1576
# Epoch 61/100 | train_loss=0.4977 acc4=0.9757 | val_loss=0.3245 acc4=0.9613
# Train | total 0.4181 | acc4 0.979 | bin 0.990 | sub_tumor 0.985 | recon 0.2804 | cls 0.1377
# Val   | total 0.3613 | acc4 0.929 | bin 0.989 | sub_tumor 0.922 | recon 0.0452 | cls 0.3161
# Epoch 62/100 | train_loss=0.4181 acc4=0.9790 | val_loss=0.3613 acc4=0.9286
# Train | total 0.4328 | acc4 0.974 | bin 0.989 | sub_tumor 0.980 | recon 0.2717 | cls 0.1611
# Val   | total 0.7352 | acc4 0.924 | bin 0.990 | sub_tumor 0.916 | recon 0.3854 | cls 0.3497
# Epoch 63/100 | train_loss=0.4328 acc4=0.9738 | val_loss=0.7352 acc4=0.9237
# Train | total 0.4341 | acc4 0.980 | bin 0.994 | sub_tumor 0.981 | recon 0.3069 | cls 0.1272
# Val   | total 0.2224 | acc4 0.959 | bin 0.986 | sub_tumor 0.966 | recon 0.0556 | cls 0.1668
# Epoch 64/100 | train_loss=0.4341 acc4=0.9802 | val_loss=0.2224 acc4=0.9594
# Train | total 0.4166 | acc4 0.982 | bin 0.991 | sub_tumor 0.988 | recon 0.3048 | cls 0.1118
# Val   | total 0.2384 | acc4 0.958 | bin 0.993 | sub_tumor 0.956 | recon 0.0332 | cls 0.2052
# Epoch 65/100 | train_loss=0.4166 acc4=0.9822 | val_loss=0.2384 acc4=0.9584
# Train | total 0.4736 | acc4 0.982 | bin 0.991 | sub_tumor 0.987 | recon 0.3547 | cls 0.1190
# Val   | total 0.2805 | acc4 0.955 | bin 0.987 | sub_tumor 0.960 | recon 0.1083 | cls 0.1722
# Epoch 66/100 | train_loss=0.4736 acc4=0.9817 | val_loss=0.2805 acc4=0.9554
# Train | total 0.4161 | acc4 0.974 | bin 0.989 | sub_tumor 0.980 | recon 0.2596 | cls 0.1565
# Val   | total 0.2742 | acc4 0.954 | bin 0.992 | sub_tumor 0.952 | recon 0.0742 | cls 0.2000
# Epoch 67/100 | train_loss=0.4161 acc4=0.9738 | val_loss=0.2742 acc4=0.9544
# Train | total 0.4176 | acc4 0.979 | bin 0.991 | sub_tumor 0.984 | recon 0.2880 | cls 0.1296
# Val   | total 0.2127 | acc4 0.961 | bin 0.993 | sub_tumor 0.960 | recon 0.0454 | cls 0.1673
# Epoch 68/100 | train_loss=0.4176 acc4=0.9795 | val_loss=0.2127 acc4=0.9613
# Train | total 0.3738 | acc4 0.981 | bin 0.990 | sub_tumor 0.987 | recon 0.2589 | cls 0.1149
# Val   | total 0.1964 | acc4 0.961 | bin 0.994 | sub_tumor 0.959 | recon 0.0288 | cls 0.1676
# Epoch 69/100 | train_loss=0.3738 acc4=0.9809 | val_loss=0.1964 acc4=0.9613
# Train | total 0.3645 | acc4 0.986 | bin 0.994 | sub_tumor 0.990 | recon 0.2690 | cls 0.0955
# Val   | total 0.2262 | acc4 0.953 | bin 0.993 | sub_tumor 0.949 | recon 0.0642 | cls 0.1620
# Epoch 70/100 | train_loss=0.3645 acc4=0.9859 | val_loss=0.2262 acc4=0.9534
# Train | total 0.3828 | acc4 0.986 | bin 0.993 | sub_tumor 0.990 | recon 0.2835 | cls 0.0993
# Val   | total 0.1671 | acc4 0.968 | bin 0.994 | sub_tumor 0.967 | recon 0.0405 | cls 0.1266
# Epoch 71/100 | train_loss=0.3828 acc4=0.9856 | val_loss=0.1671 acc4=0.9683
# Train | total 0.3521 | acc4 0.984 | bin 0.990 | sub_tumor 0.991 | recon 0.2599 | cls 0.0923
# Val   | total 0.1463 | acc4 0.968 | bin 0.986 | sub_tumor 0.976 | recon 0.0354 | cls 0.1110
# Epoch 72/100 | train_loss=0.3521 acc4=0.9837 | val_loss=0.1463 acc4=0.9683 ✅ (new best loss)
# Train | total 0.3143 | acc4 0.983 | bin 0.992 | sub_tumor 0.987 | recon 0.2194 | cls 0.0949
# Val   | total 0.2203 | acc4 0.961 | bin 0.990 | sub_tumor 0.962 | recon 0.0666 | cls 0.1537
# Epoch 73/100 | train_loss=0.3143 acc4=0.9834 | val_loss=0.2203 acc4=0.9613
# Train | total 0.3453 | acc4 0.980 | bin 0.993 | sub_tumor 0.984 | recon 0.2447 | cls 0.1006
# Val   | total 0.1775 | acc4 0.966 | bin 0.993 | sub_tumor 0.966 | recon 0.0552 | cls 0.1223
# Epoch 74/100 | train_loss=0.3453 acc4=0.9804 | val_loss=0.1775 acc4=0.9663
# Train | total 0.3814 | acc4 0.989 | bin 0.995 | sub_tumor 0.993 | recon 0.3052 | cls 0.0763
# Val   | total 0.2152 | acc4 0.965 | bin 0.992 | sub_tumor 0.965 | recon 0.0564 | cls 0.1588
# Epoch 75/100 | train_loss=0.3814 acc4=0.9894 | val_loss=0.2152 acc4=0.9653
# Train | total 0.3383 | acc4 0.987 | bin 0.993 | sub_tumor 0.992 | recon 0.2658 | cls 0.0725
# Val   | total 0.1184 | acc4 0.973 | bin 0.990 | sub_tumor 0.977 | recon 0.0175 | cls 0.1009
# Epoch 76/100 | train_loss=0.3383 acc4=0.9874 | val_loss=0.1184 acc4=0.9732 🟢⭐ (new best loss & acc)
# Train | total 0.3336 | acc4 0.986 | bin 0.992 | sub_tumor 0.991 | recon 0.2541 | cls 0.0795
# Val   | total 0.1452 | acc4 0.971 | bin 0.995 | sub_tumor 0.969 | recon 0.0493 | cls 0.0959
# Epoch 77/100 | train_loss=0.3336 acc4=0.9856 | val_loss=0.1452 acc4=0.9713
# Train | total 0.3182 | acc4 0.986 | bin 0.995 | sub_tumor 0.988 | recon 0.2330 | cls 0.0851
# Val   | total 0.1618 | acc4 0.976 | bin 0.992 | sub_tumor 0.979 | recon 0.0646 | cls 0.0972
# Epoch 78/100 | train_loss=0.3182 acc4=0.9864 | val_loss=0.1618 acc4=0.9762 💙 (new best acc)
# Train | total 0.3513 | acc4 0.984 | bin 0.994 | sub_tumor 0.987 | recon 0.2620 | cls 0.0893
# Val   | total 0.1755 | acc4 0.965 | bin 0.994 | sub_tumor 0.962 | recon 0.0243 | cls 0.1511
# Epoch 79/100 | train_loss=0.3513 acc4=0.9844 | val_loss=0.1755 acc4=0.9653
# Train | total 0.2764 | acc4 0.991 | bin 0.994 | sub_tumor 0.995 | recon 0.2171 | cls 0.0593
# Val   | total 0.1429 | acc4 0.971 | bin 0.993 | sub_tumor 0.971 | recon 0.0270 | cls 0.1159
# Epoch 80/100 | train_loss=0.2764 acc4=0.9913 | val_loss=0.1429 acc4=0.9713
# Train | total 0.3346 | acc4 0.989 | bin 0.993 | sub_tumor 0.995 | recon 0.2614 | cls 0.0731
# Val   | total 0.1442 | acc4 0.977 | bin 0.993 | sub_tumor 0.979 | recon 0.0469 | cls 0.0973
# Epoch 81/100 | train_loss=0.3346 acc4=0.9894 | val_loss=0.1442 acc4=0.9772 💙 (new best acc)
# Train | total 0.3141 | acc4 0.990 | bin 0.995 | sub_tumor 0.993 | recon 0.2510 | cls 0.0631
# Val   | total 0.1401 | acc4 0.971 | bin 0.994 | sub_tumor 0.970 | recon 0.0447 | cls 0.0955
# Epoch 82/100 | train_loss=0.3141 acc4=0.9896 | val_loss=0.1401 acc4=0.9713
# Train | total 0.2749 | acc4 0.993 | bin 0.996 | sub_tumor 0.997 | recon 0.2191 | cls 0.0557
# Val   | total 0.1046 | acc4 0.976 | bin 0.994 | sub_tumor 0.976 | recon 0.0200 | cls 0.0846
# Epoch 83/100 | train_loss=0.2749 acc4=0.9933 | val_loss=0.1046 acc4=0.9762 ✅ (new best loss)
# Train | total 0.2723 | acc4 0.993 | bin 0.996 | sub_tumor 0.996 | recon 0.2181 | cls 0.0542
# Val   | total 0.1687 | acc4 0.969 | bin 0.993 | sub_tumor 0.970 | recon 0.0586 | cls 0.1101
# Epoch 84/100 | train_loss=0.2723 acc4=0.9931 | val_loss=0.1687 acc4=0.9693
# Train | total 0.3306 | acc4 0.986 | bin 0.993 | sub_tumor 0.991 | recon 0.2529 | cls 0.0776
# Val   | total 0.1340 | acc4 0.973 | bin 0.994 | sub_tumor 0.974 | recon 0.0262 | cls 0.1078
# Epoch 85/100 | train_loss=0.3306 acc4=0.9861 | val_loss=0.1340 acc4=0.9732
# Train | total 0.2737 | acc4 0.991 | bin 0.995 | sub_tumor 0.994 | recon 0.2077 | cls 0.0659
# Val   | total 0.1180 | acc4 0.976 | bin 0.994 | sub_tumor 0.977 | recon 0.0205 | cls 0.0975
# Epoch 86/100 | train_loss=0.2737 acc4=0.9911 | val_loss=0.1180 acc4=0.9762
# Train | total 0.2772 | acc4 0.990 | bin 0.995 | sub_tumor 0.993 | recon 0.2144 | cls 0.0628
# Val   | total 0.1041 | acc4 0.975 | bin 0.995 | sub_tumor 0.975 | recon 0.0134 | cls 0.0907
# Epoch 87/100 | train_loss=0.2772 acc4=0.9899 | val_loss=0.1041 acc4=0.9752 ✅ (new best loss)
# Train | total 0.2554 | acc4 0.993 | bin 0.996 | sub_tumor 0.996 | recon 0.1944 | cls 0.0610
# Val   | total 0.1599 | acc4 0.969 | bin 0.995 | sub_tumor 0.967 | recon 0.0170 | cls 0.1429
# Epoch 88/100 | train_loss=0.2554 acc4=0.9926 | val_loss=0.1599 acc4=0.9693
# Train | total 0.2555 | acc4 0.992 | bin 0.996 | sub_tumor 0.996 | recon 0.2030 | cls 0.0524
# Val   | total 0.1075 | acc4 0.972 | bin 0.995 | sub_tumor 0.971 | recon 0.0151 | cls 0.0924
# Epoch 89/100 | train_loss=0.2555 acc4=0.9923 | val_loss=0.1075 acc4=0.9722
# Train | total 0.2438 | acc4 0.994 | bin 0.996 | sub_tumor 0.997 | recon 0.1963 | cls 0.0475
# Val   | total 0.1171 | acc4 0.970 | bin 0.995 | sub_tumor 0.969 | recon 0.0152 | cls 0.1018
# Epoch 90/100 | train_loss=0.2438 acc4=0.9938 | val_loss=0.1171 acc4=0.9703
# Train | total 0.2847 | acc4 0.993 | bin 0.996 | sub_tumor 0.996 | recon 0.2324 | cls 0.0523
# Val   | total 0.1482 | acc4 0.969 | bin 0.995 | sub_tumor 0.967 | recon 0.0321 | cls 0.1161
# Epoch 91/100 | train_loss=0.2847 acc4=0.9933 | val_loss=0.1482 acc4=0.9693
# Train | total 0.2519 | acc4 0.994 | bin 0.995 | sub_tumor 0.998 | recon 0.2049 | cls 0.0469
# Val   | total 0.1213 | acc4 0.970 | bin 0.995 | sub_tumor 0.969 | recon 0.0244 | cls 0.0969
# Epoch 92/100 | train_loss=0.2519 acc4=0.9936 | val_loss=0.1213 acc4=0.9703
# Train | total 0.2602 | acc4 0.995 | bin 0.998 | sub_tumor 0.996 | recon 0.2152 | cls 0.0450
# Val   | total 0.1298 | acc4 0.970 | bin 0.995 | sub_tumor 0.969 | recon 0.0138 | cls 0.1159
# Epoch 93/100 | train_loss=0.2602 acc4=0.9948 | val_loss=0.1298 acc4=0.9703
# Train | total 0.2661 | acc4 0.992 | bin 0.995 | sub_tumor 0.997 | recon 0.2198 | cls 0.0463
# Val   | total 0.1176 | acc4 0.970 | bin 0.995 | sub_tumor 0.969 | recon 0.0153 | cls 0.1023
# Epoch 94/100 | train_loss=0.2661 acc4=0.9921 | val_loss=0.1176 acc4=0.9703
# Train | total 0.2384 | acc4 0.994 | bin 0.997 | sub_tumor 0.996 | recon 0.1934 | cls 0.0450
# Val   | total 0.1169 | acc4 0.971 | bin 0.995 | sub_tumor 0.970 | recon 0.0158 | cls 0.1010
# Epoch 95/100 | train_loss=0.2384 acc4=0.9943 | val_loss=0.1169 acc4=0.9713
# Train | total 0.2304 | acc4 0.993 | bin 0.996 | sub_tumor 0.996 | recon 0.1826 | cls 0.0478
# Val   | total 0.1303 | acc4 0.970 | bin 0.995 | sub_tumor 0.969 | recon 0.0197 | cls 0.1105
# Epoch 96/100 | train_loss=0.2304 acc4=0.9931 | val_loss=0.1303 acc4=0.9703
# Train | total 0.2420 | acc4 0.993 | bin 0.996 | sub_tumor 0.996 | recon 0.1920 | cls 0.0500
# Val   | total 0.1292 | acc4 0.970 | bin 0.995 | sub_tumor 0.969 | recon 0.0251 | cls 0.1041
# Epoch 97/100 | train_loss=0.2420 acc4=0.9928 | val_loss=0.1292 acc4=0.9703
# Train | total 0.2172 | acc4 0.994 | bin 0.997 | sub_tumor 0.996 | recon 0.1689 | cls 0.0483
# Val   | total 0.1185 | acc4 0.970 | bin 0.994 | sub_tumor 0.970 | recon 0.0189 | cls 0.0995
# Epoch 98/100 | train_loss=0.2172 acc4=0.9943 | val_loss=0.1185 acc4=0.9703
# Train | total 0.2625 | acc4 0.993 | bin 0.996 | sub_tumor 0.995 | recon 0.2166 | cls 0.0459
# Val   | total 0.1234 | acc4 0.969 | bin 0.995 | sub_tumor 0.967 | recon 0.0177 | cls 0.1057
# Epoch 99/100 | train_loss=0.2625 acc4=0.9926 | val_loss=0.1234 acc4=0.9693
# Train | total 0.2503 | acc4 0.993 | bin 0.996 | sub_tumor 0.995 | recon 0.1993 | cls 0.0510
# Val   | total 0.1248 | acc4 0.969 | bin 0.995 | sub_tumor 0.967 | recon 0.0160 | cls 0.1088
# Epoch 100/100 | train_loss=0.2503 acc4=0.9928 | val_loss=0.1248 acc4=0.9693
# Best val loss: 0.1041. Saved to: best_AE_Loss_brain_tumor_MTL_Lat_Hier2_clean.pt

# %%
# ---- after training: plots ----

import json
import matplotlib.pyplot as plt
import torch
device = get_device()
print("Device:", device)

with open("history_AE_MTL_latent_Hier2_clean.json", "r") as f:
    history = json.load(f)
    
print(history)
best_path = "best_AE_Loss_brain_tumor_MTL_Lat_Hier2_clean.pt"
ckpt = torch.load(best_path, map_location=device)
model.load_state_dict(ckpt["model"])
model.to(device)               # <-- this is the missing bit
model.eval()

epochs = range(1, len(history["train_loss"]) + 1)
plt.figure()
plt.plot(epochs, history["train_loss"], label="Train loss")
plt.plot(epochs, history["val_loss"],   label="Val loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(epochs, history["train_acc4"], label="Train acc4")
plt.plot(epochs, history["val_acc4"],   label="Val acc4")
plt.plot(epochs, history["val_bin_acc"], label="Val_binary")
plt.plot(epochs, history["val_sub_acc"], label="Val_sub")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (4-class)")
plt.title("Training vs Validation 4-class Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Device: cuda
# {'train_loss': [2.8150897982096907, 2.2930492693834967, 2.0964475933868107, 1.9913448517865473, 1.932190198355382, 1.8126998802222827, 1.7613255231687337, 1.542913242377857, 1.579298460837638, 1.7259464268637175, 1.6409665091202992, 1.5529634199520148, 1.543774678919575, 1.3702730702881767, 1.5087733677118131, 1.5156428289885568, 1.4004242502816833, 1.3490456767601542, 1.3582095545117219, 1.1919714009407723, 1.1217790268435337, 1.1559861766229762, 1.2085444544801618, 1.037121597138962, 1.0604461634513176, 1.0368159696607306, 1.0078370575857634, 1.0203209046090003, 0.973314374508244, 0.9696485489901929, 0.9863188011811511, 0.8843139574079231, 0.8831237512059731, 0.8266175758720624, 0.7953012877171582, 0.9355290368051812, 0.7601696591566105, 0.7962187180424681, 0.7915553346718892, 0.8158703636414933, 0.6742992443613487, 0.83941650744712, 0.7005939645342307, 0.6258391966914186, 0.7606367139533015, 0.7230969934180231, 0.6342361762972162, 0.6042318921278019, 0.6062552023051989, 0.5948332779478318, 0.6013858387375822, 0.6060486664866457, 0.6239587341794873, 0.5410091804395808, 0.5400059223470122, 0.6309656261217476, 0.6325199696097044, 0.47913628716279966, 0.49018714988585743, 0.5577269897012427, 0.49774184250595543, 0.41814554395652054, 0.43281150991373724, 0.4341156406567829, 0.4166474125172832, 0.4736422888713308, 0.4160969115719937, 0.4175582917019872, 0.37377325320007776, 0.36453715019887034, 0.3827794247629619, 0.3521301031997888, 0.31430904345937294, 0.34533807602849337, 0.3814478705130001, 0.3382848336112381, 0.33356684691245014, 0.3181512660761871, 0.35131604677379724, 0.2763610418037613, 0.3345834233678213, 0.3141362322734134, 0.27486541005644466, 0.2722896948751837, 0.33055568921684036, 0.27367229337739474, 0.2772233110548246, 0.2553860105795435, 0.2554675871340355, 0.2437792242311015, 0.28470138126965794, 0.2518794205814305, 0.26019899645949357, 0.26606634250371763, 0.2383547646869527, 0.23035064428159507, 0.24200870664698063, 0.21717637131119719, 0.2625220681476121, 0.2503117300496243], 'train_acc4': [0.6680693069306931, 0.7344059405940594, 0.7599009900990099, 0.7985148514851486, 0.8158415841584158, 0.8376237623762376, 0.8386138613861386, 0.8584158415841584, 0.852970297029703, 0.8631188118811881, 0.8646039603960396, 0.8670792079207921, 0.8670792079207921, 0.8841584158415842, 0.8806930693069307, 0.8913366336633664, 0.8881188118811881, 0.8883663366336634, 0.9004950495049505, 0.9066831683168317, 0.9143564356435644, 0.9051980198019802, 0.9022277227722773, 0.905940594059406, 0.9148514851485149, 0.9128712871287129, 0.9230198019801981, 0.9183168316831684, 0.9272277227722773, 0.926980198019802, 0.9158415841584159, 0.9368811881188119, 0.932920792079208, 0.9316831683168317, 0.9425742574257425, 0.9324257425742575, 0.9393564356435643, 0.9373762376237624, 0.9415841584158415, 0.949009900990099, 0.9564356435643564, 0.9462871287128712, 0.9482673267326732, 0.9527227722772277, 0.9452970297029702, 0.9621287128712871, 0.9554455445544554, 0.9581683168316831, 0.9613861386138614, 0.9631188118811881, 0.9628712871287128, 0.9472772277227722, 0.9507425742574257, 0.9653465346534653, 0.9698019801980198, 0.969059405940594, 0.9705445544554455, 0.974009900990099, 0.9737623762376237, 0.9737623762376237, 0.9757425742574257, 0.9789603960396039, 0.9737623762376237, 0.9801980198019802, 0.9821782178217822, 0.9816831683168317, 0.9737623762376237, 0.9794554455445544, 0.9809405940594059, 0.9858910891089109, 0.9856435643564356, 0.9836633663366336, 0.9834158415841584, 0.9804455445544554, 0.9893564356435643, 0.9873762376237624, 0.9856435643564356, 0.9863861386138614, 0.9844059405940594, 0.9913366336633663, 0.9893564356435643, 0.9896039603960396, 0.9933168316831683, 0.9930693069306931, 0.9861386138613861, 0.9910891089108911, 0.9898514851485148, 0.9925742574257426, 0.9923267326732673, 0.9938118811881188, 0.9933168316831683, 0.9935643564356436, 0.9948019801980198, 0.9920792079207921, 0.9943069306930693, 0.9930693069306931, 0.9928217821782178, 0.9943069306930693, 0.9 ...
# /tmp/ipykernel_6777/3649769645.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(best_path, map_location=device)

# %%
import matplotlib.pyplot as plt
import json

filename = "history_AE_MTL_latent_Hier2.json"
with open(filename, "r") as f:
    history2 = json.load(f)

filename = "history_AE_MTL_latent_Hier2_clean.json"
with open(filename, "r") as f:
    history2_clean = json.load(f)

epochs = range(1, len(history2["train_loss"]) + 1)

# ---- Create subplots (1 row, 2 columns) ----
fig, axs = plt.subplots(1, 2, figsize=(16, 6))

# ----------------------
# Left: Loss curves
# ----------------------

ax = axs[0]
ax.plot(epochs, history2["train_acc4"], label="Train acc4")
ax.plot(epochs, history2["val_acc4"],   label="Val acc4")
ax.plot(epochs, history2["val_bin_acc"], label="Val_binary")
ax.plot(epochs, history2["val_sub_acc"], label="Val_sub")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.set_title("Training and Validation Accuracy (Data2)")
ax.legend()
ax.grid(True)

# ----------------------
# Right: Accuracy curves
# ----------------------
ax = axs[1]
ax.plot(epochs, history2_clean["train_acc4"], label="Train acc4")
ax.plot(epochs, history2_clean["val_acc4"],   label="Val acc4")
ax.plot(epochs, history2_clean["val_bin_acc"], label="Val_binary")
ax.plot(epochs, history2_clean["val_sub_acc"], label="Val_sub")
ax.set_xlabel("Epoch")
ax.set_ylabel("Accuracy")
ax.set_title("Training and Validation Accuracy (Data2 cleaned)")
ax.legend()
ax.grid(True)

plt.tight_layout()
plt.savefig("AE_MTL_plots_data2.png", bbox_inches='tight', pad_inches=0)
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
best_path = "best_AE_Loss_brain_tumor_MTL_Lat_Hier2_clean.pt"
device = get_device()
print("Device:", device)

if test_loader is not None:
    ckpt = torch.load(best_path, map_location=device)
    model.load_state_dict(ckpt["model"])
    model = model.to(device)
    model.eval()

    all_preds_4 = []
    all_true_4  = []

    flat_class_names = ["glioma_tumor", "meningioma_tumor", "pituitary_tumor", "no_tumor"]

    with torch.no_grad():
        for xb, y_bin, y_sub in test_loader:
            xb    = xb.to(device, non_blocking=True)
            y_bin = y_bin.to(device, non_blocking=True).float()
            y_sub = y_sub.to(device, non_blocking=True)

            out = model(xb)
            logit_bin  = out["logit_bin"]
            logits_sub = out["logits_sub"]

            # binary decision
            prob_bin = torch.sigmoid(logit_bin)
            pred_bin = (prob_bin >= 0.5).long()          # (B,)

            # subtype prediction
            pred_sub = logits_sub.argmax(dim=1)          # (B,)

            # 4-class predictions: 0,1,2=subtypes; 3=no_tumor
            pred_4 = torch.where(
                pred_bin == 0,
                torch.full_like(pred_sub, 3),
                pred_sub
            )

            true_4 = torch.where(
                y_bin.long() == 0,
                torch.full_like(y_sub, 3),
                y_sub
            )

            all_preds_4.append(pred_4.cpu())
            all_true_4.append(true_4.cpu())

    y_pred = torch.cat(all_preds_4).numpy()
    y_true = torch.cat(all_true_4).numpy()

    print("\nTest classification report (4-class hierarchical):")
    print(classification_report(y_true, y_pred, target_names=flat_class_names, digits=4))
    print("\nConfusion matrix:")
    print(confusion_matrix(y_true, y_pred))
# Out:
# Device: cuda
# /tmp/ipykernel_4175/1054086486.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(best_path, map_location=device)
# Test classification report (4-class hierarchical):
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.9965    0.9565    0.9761       299
# meningioma_tumor     0.9347    0.9538    0.9442       195
#  pituitary_tumor     0.9799    0.9966    0.9882       293
#         no_tumor     0.9610    1.0000    0.9801        74
#
#         accuracy                         0.9733       861
#        macro avg     0.9680    0.9767    0.9721       861
#     weighted avg     0.9738    0.9733    0.9733       861
#
#
# Confusion matrix:
# [[286  12   1   0]
#  [  1 186   5   3]
#  [  0   1 292   0]
#  [  0   0   0  74]]

# %%
import torch
import numpy as np

@torch.no_grad()
def extract_latents_4class(loader, model, device):
    """
    Extract latent vectors and corresponding 4-class labels

    4-class encoding:
      0 = glioma
      1 = meningioma
      2 = pituitary
      3 = no_tumor

    Assumes loader yields: xb, y_bin, y_sub
      y_bin: 0/1 (no_tumor / tumor)
      y_sub: 0/1/2 or -1 for no_tumor
    """
    model.eval()
    Z, Y4 = [], []

    for xb, y_bin, y_sub in loader:
        xb    = xb.to(device, non_blocking=True)
        y_bin = y_bin.to(device, non_blocking=True)
        y_sub = y_sub.to(device, non_blocking=True)

        out = model(xb, return_latent=True)
        z = out["latent"]             # (B, cls_hidden)

        # build 4-class ground truth labels
        # if y_bin == 0 -> 3 (no_tumor), else y_sub (0,1,2)
        y4 = torch.where(
            y_bin.long() == 0,
            torch.full_like(y_sub, 3),
            y_sub
        )

        Z.append(z.cpu())
        Y4.append(y4.cpu())

    Z = torch.cat(Z, dim=0).numpy()     # [N, cls_hidden]
    Y4 = torch.cat(Y4, dim=0).numpy()   # [N]
    return Z, Y4

# usage
Z, Y4 = extract_latents_4class(val_loader, model, device)
print("Latent space shape:", Z.shape)
print("Labels shape:", Y4.shape, "unique:", np.unique(Y4))
# Out:
# Latent space shape: (1009, 256)
# Labels shape: (1009,) unique: [0 1 2 3]

# %%
@torch.no_grad()
def extract_latents_tumor_only(loader, model, device):
    """
    Latents + subtype labels for tumor cases only.
    y_sub: 0=glioma, 1=meningioma, 2=pituitary
    """
    model.eval()
    Z, Y_sub_all = [], []

    for xb, y_bin, y_sub in loader:
        xb    = xb.to(device, non_blocking=True)
        y_bin = y_bin.to(device, non_blocking=True)
        y_sub = y_sub.to(device, non_blocking=True)

        out = model(xb, return_latent=True)
        z = out["latent"]  # (B, cls_hidden)

        tumor_mask = (y_bin.long() == 1) & (y_sub != -1)
        if tumor_mask.any():
            Z.append(z[tumor_mask].cpu())
            Y_sub_all.append(y_sub[tumor_mask].cpu())

    Z = torch.cat(Z, dim=0).numpy()
    Y_sub_all = torch.cat(Y_sub_all, dim=0).numpy()
    return Z, Y_sub_all

# %%
# !pip install --upgrade scikit-learn umap-learn
# Out:
# Looking in indexes: http://pulp-web-svc.pulp-system.svc.cluster.local:24880/pypi/pypi/simple/
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: umap-learn in /opt/conda/lib/python3.11/site-packages (0.5.9.post2)
# Requirement already satisfied: numpy>=1.22.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.8.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: numba>=0.51.2 in /opt/conda/lib/python3.11/site-packages (from umap-learn) (0.62.1)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.11/site-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from umap-learn) (4.66.5)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba>=0.51.2->umap-learn) (0.45.1)

# %%
import umap

# %%
import umap
import matplotlib.pyplot as plt

# Extract latent spaces
Z_val, y_val = extract_latents_4class(val_loader, model, device)
Z_test, y_test = extract_latents_4class(test_loader, model, device)

print(val_loader)
# Fit UMAP on validation set only
umap_model = umap.UMAP(
    n_components=2,
    n_neighbors=15,
    min_dist=0.1,
    metric="euclidean",
    random_state=42
)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f41993a8490>
# /opt/conda/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
import numpy as np


Z_val, y_val = extract_latents_4class(val_loader, model, device)
Z_test, y_test = extract_latents_4class(test_loader, model, device)

Z_val_2d = umap_model.fit_transform(Z_val)
# Project test set into same embedding
Z_test_2d = umap_model.transform(Z_test)

classes = ["glioma", "meningioma", "no_tumor", "pituitary"]
colors = ["tab:blue", "tab:orange", "tab:green", "tab:red"]

plt.figure(figsize=(10, 8))

# --- Plot validation (circles) ---
for c in np.unique(y_val):
    idx = (y_val == c)
    plt.scatter(
        Z_val_2d[idx, 0], Z_val_2d[idx, 1],
        c=colors[c], label=f"Val {classes[c]}",
        marker='o', alpha=0.65, s=40
    )

# --- Plot test (crosses) ---
for c in np.unique(y_test):
    idx = (y_test == c)
    plt.scatter(
        Z_test_2d[idx, 0], Z_test_2d[idx, 1],
        c=colors[c], label=f"Test {classes[c]}",
        marker='x', s=50, linewidths=1.5
    )

plt.title("UMAP Latent Space: Validation (o) + Test (x)")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("UMAP_MTL_Hierachy2.png", bbox_inches='tight', pad_inches=0)
plt.show()

# %%
import numpy as np

classes = ["glioma", "meningioma", "no_tumor", "pituitary"]
colors = ["tab:blue", "tab:orange", "tab:green", "tab:red"]

plt.figure(figsize=(10, 8))

# --- Plot validation (circles) ---
for c in np.unique(y_val):
    idx = (y_val == c)
    plt.scatter(
        Z_val_2d[idx, 0], Z_val_2d[idx, 1],
        c=colors[c], label=f"Val {classes[c]}",
        marker='o', alpha=0.65, s=40
    )

# --- Plot test (crosses) ---
for c in np.unique(y_test):
    idx = (y_test == c)
    plt.scatter(
        Z_test_2d[idx, 0], Z_test_2d[idx, 1],
        c=colors[c], label=f"Test {classes[c]}",
        marker='x', s=50, linewidths=1.5
    )

plt.title("UMAP Latent Space: Validation (o) + Test (x)")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("UMAP_MTL_Hierachy2_.png", bbox_inches='tight', pad_inches=0)
plt.show()

# %%
from torch.utils.data import Dataset

class HierarchicalWithIndex(Dataset):
    """
    Wraps a base dataset (ImageFolder or Subset(ImageFolder)) and returns:
      img, y_bin, y_sub, y_full, idx, split_name
    where:
      y_full: 0=glioma,1=meningioma,2=no_tumor,3=pituitary
      y_bin:  0=no_tumor, 1=tumor
      y_sub:  0=glioma,1=meningioma,2=pituitary, -1=no_tumor
    """
    def __init__(self, base_ds, class_names, split_name):
        self.base_ds = base_ds
        self.class_names = class_names
        self.split_name = split_name

        self.name2idx = {c: i for i, c in enumerate(class_names)}
        self.idx_no_tumor = self.name2idx["no_tumor"]

    def __len__(self):
        return len(self.base_ds)

    def __getitem__(self, idx):
        img, y_full = self.base_ds[idx]  # y_full in {0,1,2,3}

        if y_full == self.idx_no_tumor:
            y_bin = 0
            y_sub = -1
        else:
            y_bin = 1
            # map full labels (0,1,2,3) -> subtypes (0,1,2) skipping no_tumor
            # here: glioma(0)->0, meningioma(1)->1, pituitary(3)->2
            if y_full > self.idx_no_tumor:
                y_sub = y_full - 1
            else:
                y_sub = y_full

        return img, y_bin, y_sub, y_full, idx, self.split_name

# %%
from torch.utils.data import DataLoader

class_names = ["glioma", "meningioma", "no_tumor", "pituitary"]

train_an_ds = HierarchicalWithIndex(trainset, class_names, split_name="train")
val_an_ds   = HierarchicalWithIndex(valset,   class_names, split_name="val")
test_an_ds  = HierarchicalWithIndex(testset,  class_names, split_name="test")

BATCH_ANALYSIS = 32

train_an_loader = DataLoader(train_an_ds, batch_size=BATCH_ANALYSIS,
                             shuffle=False, num_workers=WORKERS, pin_memory=True)
val_an_loader   = DataLoader(val_an_ds,   batch_size=BATCH_ANALYSIS,
                             shuffle=False, num_workers=WORKERS, pin_memory=True)
test_an_loader  = DataLoader(test_an_ds,  batch_size=BATCH_ANALYSIS,
                             shuffle=False, num_workers=WORKERS, pin_memory=True)

# %%
import torch
import numpy as np

@torch.no_grad()
def extract_latents_with_meta(loader, model, device):
    """
    Returns:
      Z:      [N, latent_dim]
      y_full: [N] (0=glioma,1=meningioma,2=no_tumor,3=pituitary)
      split:  [N] (array of strings: 'train'/'val'/'test')
      idx_ds: [N] index into the corresponding base dataset (trainset/valset/testset)
    """
    model.eval()
    Z = []
    y_full_list = []
    split_list = []
    idx_list = []

    for xb, y_bin, y_sub, y_full, idx, split_name in loader:
        xb = xb.to(device, non_blocking=True)
        out = model(xb, return_latent=True)
        z = out["latent"].cpu().numpy()   # (B, latent_dim)

        Z.append(z)
        y_full_list.append(y_full.numpy())
        idx_list.append(idx.numpy())
        # split_name is a tuple/list of identical strings per batch
        split_list.extend(split_name)

    Z = np.concatenate(Z, axis=0)
    y_full = np.concatenate(y_full_list, axis=0)
    idx_ds = np.concatenate(idx_list, axis=0)
    split = np.array(split_list)

    return Z, y_full, split, idx_ds

Z_tr, y_tr, split_tr, idx_tr = extract_latents_with_meta(train_an_loader, model, device)
Z_va, y_va, split_va, idx_va = extract_latents_with_meta(val_an_loader,   model, device)
Z_te, y_te, split_te, idx_te = extract_latents_with_meta(test_an_loader,  model, device)

# concatenate all
Z_all = np.concatenate([Z_tr, Z_va, Z_te], axis=0)
y_all = np.concatenate([y_tr, y_va, y_te], axis=0)
split_all = np.concatenate([split_tr, split_va, split_te], axis=0)
idx_all = np.concatenate([idx_tr, idx_va, idx_te], axis=0)

print("Z_all:", Z_all.shape)
# Out:
# Z_all: (7023, 256)

# %%
glioma_idx = class_names.index("glioma")

is_train = (split_all == "train")
is_val   = (split_all == "val")
is_test  = (split_all == "test")

is_glioma = (y_all == glioma_idx)
is_nonglioma = (y_all != glioma_idx)

train_glioma_mask = is_glioma & is_train    # or (is_train | is_val) if you prefer
test_glioma_mask  = is_glioma & is_test

Z_train_g = Z_all[train_glioma_mask]
Z_test_g  = Z_all[test_glioma_mask]

# centroid of training gliomas
mu_g = Z_train_g.mean(axis=0)

# L2 distance from centroid
d_test = np.linalg.norm(Z_test_g - mu_g, axis=1)

# sort test gliomas by distance (largest = most outlier)
order = np.argsort(-d_test)
top_k = 20   # number of outliers you want to inspect
top_outlier_idx_in_test = order[:top_k]

# map back to global indices in Z_all
global_indices_test_g = np.where(test_glioma_mask)[0]
outlier_global_indices = global_indices_test_g[top_outlier_idx_in_test]

# %%
# pool of all non-glioma samples across train/val/test
nong_mask = is_nonglioma
Z_nong = Z_all[nong_mask]
global_indices_nong = np.where(nong_mask)[0]

def nearest_non_glioma(z):
    # Euclidean distance to all non-gliomas
    diff = Z_nong - z[None, :]
    dist = np.linalg.norm(diff, axis=1)
    j = np.argmin(dist)
    return global_indices_nong[j], dist[j]

pairs = []  # list of (global_idx_outlier, global_idx_neighbor, dist_outlier, dist_neighbor)

for g_idx in outlier_global_indices:
    z_out = Z_all[g_idx]
    neigh_global_idx, d_neigh = nearest_non_glioma(z_out)
    d_out = np.linalg.norm(z_out - mu_g)
    pairs.append((g_idx, neigh_global_idx, d_out, d_neigh))

# %%
def get_path(split, idx_ds):
    """
    Return the *absolute file path* of the sample in the underlying dataset.
    Works for both ImageFolder and Subset(ImageFolder).
    """
    if split == "train":
        base = trainset
    elif split == "val":
        base = valset
    else:
        base = testset

    # If dataset is a Subset(ImageFolder)
    if hasattr(base, 'dataset') and hasattr(base, 'indices'):
        true_idx = base.indices[idx_ds]
        return base.dataset.samples[true_idx][0]

    # Else if it's a plain ImageFolder
    if hasattr(base, 'samples'):
        return base.samples[idx_ds][0]

    raise RuntimeError("Dataset type not supported for path extraction.")

# %%
print("\n===== Outlier Summary =====")

for rank, (g_idx, n_idx, d_out, d_neigh) in enumerate(pairs, start=1):
    split_g = split_all[g_idx]
    idx_g   = idx_all[g_idx]
    path_g  = get_path(split_g, idx_g)

    split_n = split_all[n_idx]
    idx_n   = idx_all[n_idx]
    path_n  = get_path(split_n, idx_n)

    print(f"\nOutlier #{rank}")
    print(f"  Outlier glioma:")
    print(f"    split       = {split_g}")
    print(f"    class       = {class_names[y_all[g_idx]]}")
    print(f"    idx_ds      = {idx_g}")
    print(f"    file        = {path_g}")
    print(f"    dist_to_centroid = {d_out:.3f}")

    print(f"  Nearest non-glioma:")
    print(f"    split       = {split_n}")
    print(f"    class       = {class_names[y_all[n_idx]]}")
    print(f"    idx_ds      = {idx_n}")
    print(f"    file        = {path_n}")
    print(f"    distance_pair = {d_neigh:.3f}")
# Out:
# ===== Outlier Summary =====
#
# Outlier #1
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 43
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0043.jpg
#     dist_to_centroid = 12.791
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 2850
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_0467.jpg
#     distance_pair = 0.754
#
# Outlier #2
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 272
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0272.jpg
#     dist_to_centroid = 12.221
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 2233
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_1115.jpg
#     distance_pair = 0.583
#
# Outlier #3
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 209
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0209.jpg
#     dist_to_centroid = 11.684
#   Nearest non-glioma:
#     split       = train
#     class       = no_tumor
#     idx_ds      = 545
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/notumor/Tr-no_0948.jpg
#     distance_pair = 8.312
#
# Outlier #4
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 221
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0221.jpg
#     dist_to_centroid = 11.602
#   Nearest non-glioma:
#     split       = test
#     class       = meningioma
#     idx_ds      = 392
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/meningioma/Te-me_0092.jpg
#     distance_pair = 1.586
#
# Outlier #5
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 259
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0259.jpg
#     dist_to_centroid = 11.292
#   Nearest non-glioma:
#     split       = test
#     class       = meningioma
#     idx_ds      = 597
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/meningioma/Te-me_0297.jpg
#     distance_pair = 0.786
#
# Outlier #6
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 136
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0136.jpg
#     dist_to_centroid = 11.256
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 2016
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_1275.jpg
#     distance_pair = 4.600
#
# Outlier #7
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 30
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0030.jpg
#     dist_to_centroid = 10.968
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 3336
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_0527.jpg
#     distance_pair = 0.574
#
# Outlier #8
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 236
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0236.jpg
#     dist_to_centroid = 10.912
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 3336
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_0527.jpg
#     distance_pair = 0.390
#
# Outlier #9
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 280
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0280.jpg
#     dist_to_centroid = 10.612
#   Nearest non-glioma:
#     split       = test
#     class       = meningioma
#     idx_ds      = 539
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/meningioma/Te-me_0239.jpg
#     distance_pair = 1.043
#
# Outlier #10
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 247
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0247.jpg
#     dist_to_centroid = 10.594
#   Nearest non-glioma:
#     split       = val
#     class       = meningioma
#     idx_ds      = 86
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_0769.jpg
#     distance_pair = 1.246
#
# Outlier #11
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 237
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0237.jpg
#     dist_to_centroid = 10.508
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 2349
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_1011.jpg
#     distance_pair = 0.561
#
# Outlier #12
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 159
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0159.jpg
#     dist_to_centroid = 10.479
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 4038
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_0759.jpg
#     distance_pair = 0.442
#
# Outlier #13
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 235
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0235.jpg
#     dist_to_centroid = 10.410
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 3883
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_0484.jpg
#     distance_pair = 1.106
#
# Outlier #14
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 79
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0079.jpg
#     dist_to_centroid = 10.193
#   Nearest non-glioma:
#     split       = train
#     class       = no_tumor
#     idx_ds      = 3460
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/notumor/Tr-no_1400.jpg
#     distance_pair = 3.682
#
# Outlier #15
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 265
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0265.jpg
#     dist_to_centroid = 10.100
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 2770
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_0881.jpg
#     distance_pair = 1.054
#
# Outlier #16
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 173
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0173.jpg
#     dist_to_centroid = 10.012
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 2016
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_1275.jpg
#     distance_pair = 4.333
#
# Outlier #17
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 267
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0267.jpg
#     dist_to_centroid = 9.971
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 4052
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_0781.jpg
#     distance_pair = 0.812
#
# Outlier #18
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 260
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0260.jpg
#     dist_to_centroid = 9.907
#   Nearest non-glioma:
#     split       = train
#     class       = meningioma
#     idx_ds      = 2976
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/meningioma/Tr-me_1215.jpg
#     distance_pair = 0.740
#
# Outlier #19
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 219
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0219.jpg
#     dist_to_centroid = 9.846
#   Nearest non-glioma:
#     split       = train
#     class       = pituitary
#     idx_ds      = 262
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/pituitary/Tr-pi_0931.jpg
#     distance_pair = 2.576
#
# Outlier #20
#   Outlier glioma:
#     split       = test
#     class       = glioma
#     idx_ds      = 226
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Testing/glioma/Te-gl_0226.jpg
#     dist_to_centroid = 9.810
#   Nearest non-glioma:
#     split       = train
#     class       = pituitary
#     idx_ds      = 732
#     file        = /home/jovyan/nnunet2-mig-7g-80gb-datavol-1/data2/Training/pituitary/Tr-pi_0998.jpg
#     distance_pair = 7.643

# %%
for rank, (g_idx, n_idx, d_out, d_neigh) in enumerate(pairs, start=1):
    print(f"\nOutlier #{rank}")
    print(f"  Outlier:   split={split_all[g_idx]}, class={class_names[y_all[g_idx]]}, "
          f"idx_ds={idx_all[g_idx]}, dist_to_glioma_centroid={d_out:.3f}")
    print(f"  Neighbour: split={split_all[n_idx]}, class={class_names[y_all[n_idx]]}, "
          f"idx_ds={idx_all[n_idx]}, dist_outlier_to_neighbour={d_neigh:.3f}")
# Out:
# Outlier #1
#   Outlier:   split=test, class=glioma, idx_ds=43, dist_to_glioma_centroid=12.791
#   Neighbour: split=train, class=meningioma, idx_ds=2850, dist_outlier_to_neighbour=0.754
#
# Outlier #2
#   Outlier:   split=test, class=glioma, idx_ds=272, dist_to_glioma_centroid=12.221
#   Neighbour: split=train, class=meningioma, idx_ds=2233, dist_outlier_to_neighbour=0.583
#
# Outlier #3
#   Outlier:   split=test, class=glioma, idx_ds=209, dist_to_glioma_centroid=11.684
#   Neighbour: split=train, class=no_tumor, idx_ds=545, dist_outlier_to_neighbour=8.312
#
# Outlier #4
#   Outlier:   split=test, class=glioma, idx_ds=221, dist_to_glioma_centroid=11.602
#   Neighbour: split=test, class=meningioma, idx_ds=392, dist_outlier_to_neighbour=1.586
#
# Outlier #5
#   Outlier:   split=test, class=glioma, idx_ds=259, dist_to_glioma_centroid=11.292
#   Neighbour: split=test, class=meningioma, idx_ds=597, dist_outlier_to_neighbour=0.786
#
# Outlier #6
#   Outlier:   split=test, class=glioma, idx_ds=136, dist_to_glioma_centroid=11.256
#   Neighbour: split=train, class=meningioma, idx_ds=2016, dist_outlier_to_neighbour=4.600
#
# Outlier #7
#   Outlier:   split=test, class=glioma, idx_ds=30, dist_to_glioma_centroid=10.968
#   Neighbour: split=train, class=meningioma, idx_ds=3336, dist_outlier_to_neighbour=0.574
#
# Outlier #8
#   Outlier:   split=test, class=glioma, idx_ds=236, dist_to_glioma_centroid=10.912
#   Neighbour: split=train, class=meningioma, idx_ds=3336, dist_outlier_to_neighbour=0.390
#
# Outlier #9
#   Outlier:   split=test, class=glioma, idx_ds=280, dist_to_glioma_centroid=10.612
#   Neighbour: split=test, class=meningioma, idx_ds=539, dist_outlier_to_neighbour=1.043
#
# Outlier #10
#   Outlier:   split=test, class=glioma, idx_ds=247, dist_to_glioma_centroid=10.594
#   Neighbour: split=val, class=meningioma, idx_ds=86, dist_outlier_to_neighbour=1.246
#
# Outlier #11
#   Outlier:   split=test, class=glioma, idx_ds=237, dist_to_glioma_centroid=10.508
#   Neighbour: split=train, class=meningioma, idx_ds=2349, dist_outlier_to_neighbour=0.561
#
# Outlier #12
#   Outlier:   split=test, class=glioma, idx_ds=159, dist_to_glioma_centroid=10.479
#   Neighbour: split=train, class=meningioma, idx_ds=4038, dist_outlier_to_neighbour=0.442
#
# Outlier #13
#   Outlier:   split=test, class=glioma, idx_ds=235, dist_to_glioma_centroid=10.410
#   Neighbour: split=train, class=meningioma, idx_ds=3883, dist_outlier_to_neighbour=1.106
#
# Outlier #14
#   Outlier:   split=test, class=glioma, idx_ds=79, dist_to_glioma_centroid=10.193
#   Neighbour: split=train, class=no_tumor, idx_ds=3460, dist_outlier_to_neighbour=3.682
#
# Outlier #15
#   Outlier:   split=test, class=glioma, idx_ds=265, dist_to_glioma_centroid=10.100
#   Neighbour: split=train, class=meningioma, idx_ds=2770, dist_outlier_to_neighbour=1.054
#
# Outlier #16
#   Outlier:   split=test, class=glioma, idx_ds=173, dist_to_glioma_centroid=10.012
#   Neighbour: split=train, class=meningioma, idx_ds=2016, dist_outlier_to_neighbour=4.333
#
# Outlier #17
#   Outlier:   split=test, class=glioma, idx_ds=267, dist_to_glioma_centroid=9.971
#   Neighbour: split=train, class=meningioma, idx_ds=4052, dist_outlier_to_neighbour=0.812
#
# Outlier #18
#   Outlier:   split=test, class=glioma, idx_ds=260, dist_to_glioma_centroid=9.907
#   Neighbour: split=train, class=meningioma, idx_ds=2976, dist_outlier_to_neighbour=0.740
#
# Outlier #19
#   Outlier:   split=test, class=glioma, idx_ds=219, dist_to_glioma_centroid=9.846
#   Neighbour: split=train, class=pituitary, idx_ds=262, dist_outlier_to_neighbour=2.576
#
# Outlier #20
#   Outlier:   split=test, class=glioma, idx_ds=226, dist_to_glioma_centroid=9.810
#   Neighbour: split=train, class=pituitary, idx_ds=732, dist_outlier_to_neighbour=7.643

# %%
import matplotlib.pyplot as plt

def get_img(split, idx_ds):
    if split == "train":
        img, _ = trainset[idx_ds]
    elif split == "val":
        img, _ = valset[idx_ds]
    else:
        img, _ = testset[idx_ds]
    # img is a tensor [C,H,W]; convert to numpy for plotting
    if isinstance(img, torch.Tensor):
        img_np = img.detach().cpu().numpy()
        if img_np.ndim == 3 and img_np.shape[0] == 1:
            img_np = img_np[0]
        elif img_np.ndim == 3:
            img_np = img_np.transpose(1, 2, 0)
    else:
        img_np = np.array(img)
    return img_np

k_vis = min(top_k, len(pairs))

fig, axes = plt.subplots(k_vis, 2, figsize=(6, 3*k_vis))
if k_vis == 1:
    axes = np.array([axes])  # ensure 2D

for row, (g_idx, n_idx, d_out, d_neigh) in enumerate(pairs[:k_vis]):
    split_g = split_all[g_idx]; idx_g = idx_all[g_idx]
    split_n = split_all[n_idx]; idx_n = idx_all[n_idx]

    img_g = get_img(split_g, idx_g)
    img_n = get_img(split_n, idx_n)

    ax1, ax2 = axes[row]

    ax1.imshow(img_g, cmap="gray")
    ax1.set_title(f"Outlier glioma\n{split_g}, idx {idx_g}\n"
                  f"d_centroid={d_out:.2f}")
    ax1.axis("off")

    ax2.imshow(img_n, cmap="gray")
    ax2.set_title(f"Nearest non-glioma: {class_names[y_all[n_idx]]}\n"
                  f"{split_n}, idx {idx_n}\n"
                  f"d_pair={d_neigh:.2f}")
    ax2.axis("off")

plt.tight_layout()
plt.show()
